# %%
# Support Vector Machine

# %% [markdown]
# ### Set Up

# %%
# install required packages
import requests
import pandas as pd
import json
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.cm as cm

from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, scale
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score, recall_score

from itertools import cycle, islice

from pandas.plotting import parallel_coordinates


#!pip install shap
import shap
import pyarrow

# %% [markdown]
# ### National Park Service Data

# %% [markdown]
# #### National Park Service Sites

# %%
# National Park Service API Set Up
nps_url_base = "developer.nps.gov/api/v1"

my_api_key = 'your_API_key_here'

nps_url_request = "https://developer.nps.gov/api/v1/parks?limit=500&get=designation,fullName,id,name,parkCode,states&for=parkCode:*&api_key=" + my_api_key

# need to update limit to 500 for full run

# %%
# Execute API request
response = requests.get(nps_url_request)

# %%
# Check status of API request, report status, and if good transform data into dataframe and print column names
if response.status_code == 200:
    print('Successful API download')
    nps_api_exp = json.loads(response.text)
    nps_data = pd.DataFrame(nps_api_exp['data'])
    print(nps_data.columns)
else: print(f'API download failed. Error code: {response.status_code}')
# Out:
# Successful API download
# Index(['id', 'url', 'fullName', 'parkCode', 'description', 'latitude',
#        'longitude', 'latLong', 'activities', 'topics', 'states', 'contacts',
#        'entranceFees', 'entrancePasses', 'fees', 'directionsInfo',
#        'directionsUrl', 'operatingHours', 'addresses', 'images', 'weatherInfo',
#        'name', 'designation', 'multimedia', 'relevanceScore'],
#       dtype='str')

# %%
# Select parameters of interest from API data set
nps_sites0 = nps_data[['fullName','name','parkCode','designation','states']]

# Rename columns
nps_sites0 = nps_sites0.rename(columns={'fullName': 'Site_Full_Name', 'name': 'Site_Name', 'parkCode': 'Park_Code', 'designation': 'Designation', 'states': 'State List'})

# Capitalize park code for consistent formatting
nps_sites0['Park_Code'] = nps_sites0['Park_Code'].str.upper()

#nps_sites.head()

# %%
nps_sites_nodesig = nps_sites0[nps_sites0['Designation']==""]
nps_sites_nodesig

nps_sites_nodesig['Designation'] = 'Undesignated'

#nps_sites_nodesig

# %%
nps_sites_desig = nps_sites0[nps_sites0['Designation']!=""]
nps_sites_desig
# Out:
#                                         Site_Full_Name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 4              African Burial Ground National Monument
# 5                  Agate Fossil Beds National Monument
# ..                                                 ...
# 469  Yorktown Battlefield Part of Colonial National...
# 470                             Yosemite National Park
# 471                      Yucca House National Monument
# 472           Yukon - Charley Rivers National Preserve
# 473                                 Zion National Park
#
#                       Site_Name Park_Code  \
# 0    Abraham Lincoln Birthplace      ABLI
# 1                        Acadia      ACAD
# 2                         Adams      ADAM
# 4         African Burial Ground      AFBG
# 5             Agate Fossil Beds      AGFO
# ..                          ...       ...
# 469        Yorktown Battlefield      YORK
# 470                    Yosemite      YOSE
# 471                 Yucca House      YUHO
# 472      Yukon - Charley Rivers      YUCH
# 473                        Zion      ZION
#
#                                    Designation State List
# 0                     National Historical Park         KY
# 1                                National Park         ME
# 2                     National Historical Park         MA
# 4                            National Monument         NY
# 5                            National Monument         NE
# ..                                         ...        ...
# 469  Part of Colonial National Historical Park         VA
# 470                              National Park         CA
# 471                          National Monument         CO
# 472                          National Preserve         AK
# 473                              National Park         UT
#
# [439 rows x 5 columns]

# %%
nps_sites = pd.concat([nps_sites_desig, nps_sites_nodesig], ignore_index = True)
nps_sites.sort_values(by = 'Park_Code')
nps_sites.head()
# Out:
#                                       Site_Full_Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#                     Site_Name Park_Code               Designation State List
# 0  Abraham Lincoln Birthplace      ABLI  National Historical Park         KY
# 1                      Acadia      ACAD             National Park         ME
# 2                       Adams      ADAM  National Historical Park         MA
# 3       African Burial Ground      AFBG         National Monument         NY
# 4           Agate Fossil Beds      AGFO         National Monument         NE

# %%
# Break out list of sites by individual states
# (will include duplicate listings for parks spanning multiple states)
#nps_sites_state = nps_sites[['Park_Code','State List','Designation']]

#nps_sites_state['State Abb'] = nps_sites['State List']

#nps_sites_state['State Abb'] = (nps_sites_state['State List'].str.split(','))

#nps_sites_state = nps_sites_state.explode('State Abb')

#nps_sites_state = nps_sites_state.reset_index(drop=True)

# %% [markdown]
# #### Visitor Data

# %%
# Visitation Data

visit_file_1 = "Data/Annual Visitation By Park (1979-1985).csv"

visit_1_load = pd.read_csv(visit_file_1)

#visit_1_load.head(10)

visit_1_load.columns = visit_1_load.iloc[5]

visit_1_load = visit_1_load.iloc[6:].reset_index(drop = True)

visit_1 = visit_1_load.drop(visit_1_load.columns[[0,9,10,11]], axis=1)

#visit_1.head(10)

# Convert from pivot table to flat table format

visit_1_fl = visit_1.set_index('Park Name').stack().reset_index()

visit_1_fl.rename(columns={5: "Year", 0: "Visitors"}, inplace=True)

#visit_1_fl.head(10)

visit_file_2 = "Data/Annual Visitation By Park (1986-2006).csv"

visit_2_load = pd.read_csv(visit_file_2)

#visit_2_load.head(10)

visit_2_load.columns = visit_2_load.iloc[5]

visit_2_load = visit_2_load.iloc[6:].reset_index(drop = True)

#visit_2_load.head(10)

visit_2 = visit_2_load.drop(visit_2_load.columns[[0,11,12,24]], axis=1)

#visit_2.head(10)

# Convert from pivot table to flat table format

visit_2_fl = visit_2.set_index('Park Name').stack().reset_index()

visit_2_fl.rename(columns={5: "Year", 0: "Visitors"}, inplace=True)

#visit_2_fl.head()

visit_file_3 = "Data/Annual Visitation By Park (2006-2025).csv"

visit_3_load = pd.read_csv(visit_file_3)

#visit_3_load.head(10)

visit_3_load.columns = visit_3_load.iloc[5]

visit_3_load = visit_3_load.iloc[6:].reset_index(drop = True)

#visit_3_load.head(10)

visit_3 = visit_3_load.drop(visit_3_load.columns[[0,11,12,24]], axis=1)

#visit_3.head(10)

# Convert from pivot table to flat table format

visit_3_fl = visit_3.set_index('Park Name').stack().reset_index()

visit_3_fl.rename(columns={5: "Year", 0: "Visitors"}, inplace=True)

#visit_3_fl.head()

# %%
# Concatenate Visitor Totals from Tables

visitors = pd.concat([visit_1_fl, visit_2_fl, visit_3_fl], ignore_index=True)

visitors = visitors.sort_values(by=['Park Name','Year'])

visitors.head()

#print(visitors.shape)
# Out:
#                         Park Name  Year Visitors
# 0  Abraham Lincoln Birthplace NHP  1979  271,231
# 1  Abraham Lincoln Birthplace NHP  1980  239,074
# 2  Abraham Lincoln Birthplace NHP  1981  252,245
# 3  Abraham Lincoln Birthplace NHP  1982  318,707
# 4  Abraham Lincoln Birthplace NHP  1983  256,126

# %%
# Remove any rows without park name
visitors.dropna(subset = ['Park Name'], inplace = True)

#print(visitors.shape)

# Convert numbers strings to numbers
visitors['Visitors'] = visitors['Visitors'].str.replace(",","")

visitors['Visitors'] = pd.to_numeric(visitors['Visitors'])
visitors['Year'] = pd.to_numeric(visitors['Year'])

# Remove entries with no visitor numbers
visitors['Visitors'] = visitors['Visitors'].dropna()
#visitors['Visitors Scaled'] = visitors['Visitors Scaled'].fillna(0)

#visitors['Visitors'].dtype

# %%
# Scale visitor numbers

vis_max = max(visitors['Visitors'])

visitors['Visitors Scaled'] = visitors['Visitors']/vis_max

# %%
# Import list of Site Abbreviations

visit_abb_file = "Data/Visitor_Sites_Codes.csv"

visitor_park_abb_load = pd.read_csv(visit_abb_file)

#visitor_park_abb_load.head()

visitor_park_abb = visitor_park_abb_load[['Park Name','Park_Code']]

#visitor_park_abb.head()

# Join site abbreviations to data frame

visitors = pd.merge(visitors, visitor_park_abb, on='Park Name', how='left')

visitors['Code_Year'] = visitors['Park_Code'] + '-' + visitors['Year'].astype(str)

visitors.head()
# Out:
#                         Park Name  Year  Visitors  Visitors Scaled Park_Code  \
# 0  Abraham Lincoln Birthplace NHP  1979  271231.0         0.012461      ABLI
# 1  Abraham Lincoln Birthplace NHP  1980  239074.0         0.010983      ABLI
# 2  Abraham Lincoln Birthplace NHP  1981  252245.0         0.011588      ABLI
# 3  Abraham Lincoln Birthplace NHP  1982  318707.0         0.014642      ABLI
# 4  Abraham Lincoln Birthplace NHP  1983  256126.0         0.011767      ABLI
#
#    Code_Year
# 0  ABLI-1979
# 1  ABLI-1980
# 2  ABLI-1981
# 3  ABLI-1982
# 4  ABLI-1983

# %%
visitors.describe()
# Out:
#                Year      Visitors  Visitors Scaled
# count  17247.000000  1.609500e+04     16095.000000
# mean    2003.127732  8.044333e+05         0.036956
# std       13.390632  1.781894e+06         0.081862
# min     1979.000000  0.000000e+00         0.000000
# 25%     1992.000000  5.174150e+04         0.002377
# 50%     2004.000000  2.053870e+05         0.009436
# 75%     2015.000000  7.563200e+05         0.034746
# max     2025.000000  2.176718e+07         1.000000

# %%
#sel1 = visitors[(visitors['annual_chg_pct']<-0.9) & (visitors['annual_chg_pct']>-10)]
#sel1
#sns.countplot(data = visitors, x = 'annual_chg_pct')
#plt.show()

# %%
look = visitors[visitors['Visitors'] == 0]
look
# Out:
#                                    Park Name  Year  Visitors  Visitors Scaled  \
# 492                      Aniakchak NM & PRES  1995       0.0              0.0
# 818         Arlington House The R.E. Lee MEM  2019       0.0              0.0
# 819         Arlington House The R.E. Lee MEM  2020       0.0              0.0
# 1028        Belmont-Paul Women's Equality NM  2021       0.0              0.0
# 1029        Belmont-Paul Women's Equality NM  2022       0.0              0.0
# 2281                     Cape Krusenstern NM  2014       0.0              0.0
# 2282                     Cape Krusenstern NM  2015       0.0              0.0
# 2543              Carter G. Woodson Home NHS  2021       0.0              0.0
# 2544              Carter G. Woodson Home NHS  2022       0.0              0.0
# 2545              Carter G. Woodson Home NHS  2023       0.0              0.0
# 3363                        Clara Barton NHS  2016       0.0              0.0
# 3364                        Clara Barton NHS  2017       0.0              0.0
# 3368                        Clara Barton NHS  2021       0.0              0.0
# 4368                     Edgar Allan Poe NHS  2021       0.0              0.0
# 4372                     Edgar Allan Poe NHS  2025       0.0              0.0
# 4741                       Federal Hall NMEM  2005       0.0              0.0
# 7615                    Hamilton Grange NMEM  1980       0.0              0.0
# 7616                    Hamilton Grange NMEM  1981       0.0              0.0
# 7617                    Hamilton Grange NMEM  1982       0.0              0.0
# 7628                    Hamilton Grange NMEM  1993       0.0              0.0
# 7629                    Hamilton Grange NMEM  1994       0.0              0.0
# 7630                    Hamilton Grange NMEM  1995       0.0              0.0
# 7631                    Hamilton Grange NMEM  1996       0.0              0.0
# 7632                    Hamilton Grange NMEM  1997       0.0              0.0
# 7642                    Hamilton Grange NMEM  2007       0.0              0.0
# 7645                    Hamilton Grange NMEM  2010       0.0              0.0
# 8783                     John F. Kennedy NHS  2021       0.0              0.0
# 9045                        Katmai NP & PRES  1995       0.0              0.0
# 9460                         Kobuk Valley NP  2014       0.0              0.0
# 9461                         Kobuk Valley NP  2015       0.0              0.0
# 9563                         Lake Chelan NRA  1990       0.0              0.0
# 10216   Longfellow House Washington's HQ NHS  1999       0.0              0.0
# 10217   Longfellow House Washington's HQ NHS  2000       0.0              0.0
# 10218   Longfellow House Washington's HQ NHS  2001       0.0              0.0
# 10727  Mary McLeod Bethune Council House NHS  2021       0.0              0.0
# 11031                            Monocacy NB  1991       0.0              0.0
# 11532        National Park of American Samoa  2003       0.0              0.0
# 11985                           Noatak NPRES  2014       0.0              0.0
# 11986                           Noatak NPRES  2015       0.0              0.0
# 12596                Pennsylvania Avenue NHS  2015       0.0              0.0
# 12597                Pennsylvania Avenue NHS  2016       0.0              0.0
# 12602                Pennsylvania Avenue NHS  2021       0.0              0.0
# 13704                          Ross Lake NRA  1990       0.0              0.0
# 14782                 Springfield Armory NHS  1988       0.0              0.0
# 14988                           Stonewall NM  2020       0.0              0.0
# 15122               Thaddeus Kosciuszko NMEM  2020       0.0              0.0
# 15123               Thaddeus Kosciuszko NMEM  2021       0.0              0.0
# 15341                      Thomas Edison NHP  2004       0.0              0.0
# 15342                      Thomas Edison NHP  2005       0.0              0.0
# 16330                    Washington Monument  2001       0.0              0.0
# 16341                    Washington Monument  2012       0.0              0.0
# 16342                    Washington Monument  2013       0.0              0.0
# 16346                    Washington Monument  2017       0.0              0.0
# 16347                    Washington Monument  2018       0.0              0.0
#
#       Park_Code  Code_Year
# 492        ANIA  ANIA-1995
# 818        ARHO  ARHO-2019
# 819        ARHO  ARHO-2020
# 1028       BEPA  BEPA-2021
# 1029       BEPA  BEPA-2022
# 2281       CAKR  CAKR-2014
# 2282       CAKR  CAKR-2015
# 2543       CAWO  CAWO-2021
# 2544       CAWO  CAWO-2022
# 2545       CAWO  CAWO-2023
# 3363       CLBA  CLBA-2016
# 3364       CLBA  CLBA-2017
# 3368       CLBA  CLBA-2021
# 4368       EDAL  EDAL-2021
# 4372       EDAL  EDAL-2025
# 4741       FEHA  FEHA-2005
# 7615       HAGR  HAGR-1980
# 7616       HAGR  HAGR-1981
# 7617       HAGR  HAGR-1982
# 7628       HAGR  HAGR-1993
# 7629       HAGR  HAGR-1994
# 7630       HAGR  HAGR-1995
# 7631       HAGR  HAGR-1996
# 7632       HAGR  HAGR-1997
# 7642       HAGR  HAGR-2007
# 7645       HAGR  HAGR-2010
# 8783       JOFI  JOFI-2021
# 9045       KATM  KATM-1995
# 9460       KOVA  KOVA-2014
# 9461       KOVA  KOVA-2015
# 9563       NOCA  NOCA-1990
# 10216      LONG  LONG-1999
# 10217      LONG  LONG-2000
# 10218      LONG  LONG-2001
# 10727      MAMC  MAMC-2021
# 11031      MONO  MONO-1991
# 11532      NPSA  NPSA-2003
# 11985      NOAT  NOAT-2014
# 11986      NOAT  NOAT-2015
# 12596      PAAV  PAAV-2015
# 12597      PAAV  PAAV-2016
# 12602      PAAV  PAAV-2021
# 13704      NOCA  NOCA-1990
# 14782      SPRA  SPRA-1988
# 14988      STON  STON-2020
# 15122      THKO  THKO-2020
# 15123      THKO  THKO-2021
# 15341      EDIS  EDIS-2004
# 15342      EDIS  EDIS-2005
# 16330      WAMO  WAMO-2001
# 16341      WAMO  WAMO-2012
# 16342      WAMO  WAMO-2013
# 16346      WAMO  WAMO-2017
# 16347      WAMO  WAMO-2018

# %%
viz0 = visitors[visitors['Visitors'] == 0]
viz0.shape
# Out:
# (54, 6)

# %%
# Calculate the change in annual visitor numbers from previous year 

# check to see if previous row is from same park
visitors['site_chk'] = (visitors['Park_Code'] == visitors['Park_Code'].shift(1)).astype(int)

# calculate the difference (whole and percentage) of visitors from the previous year (for the same site)
visitors['annual_chg'] = (visitors['Visitors'].diff()) * visitors['site_chk']
visitors['annual_chg_pct'] = (visitors['Visitors'].diff()) * visitors['site_chk'] / visitors['Visitors'].shift(1)

# replace infinite values with 15
visitors['annual_chg_pct'] = visitors['annual_chg_pct'].replace(np.inf, 15)

# %%
visitors.head()
# Out:
#                         Park Name  Year  Visitors  Visitors Scaled Park_Code  \
# 0  Abraham Lincoln Birthplace NHP  1979  271231.0         0.012461      ABLI
# 1  Abraham Lincoln Birthplace NHP  1980  239074.0         0.010983      ABLI
# 2  Abraham Lincoln Birthplace NHP  1981  252245.0         0.011588      ABLI
# 3  Abraham Lincoln Birthplace NHP  1982  318707.0         0.014642      ABLI
# 4  Abraham Lincoln Birthplace NHP  1983  256126.0         0.011767      ABLI
#
#    Code_Year  site_chk  annual_chg  annual_chg_pct
# 0  ABLI-1979         0         NaN             NaN
# 1  ABLI-1980         1    -32157.0       -0.118559
# 2  ABLI-1981         1     13171.0        0.055092
# 3  ABLI-1982         1     66462.0        0.263482
# 4  ABLI-1983         1    -62581.0       -0.196359

# %%
# remove the years with no previous year to track change
visitors = visitors[abs(visitors['annual_chg_pct']) > 0]
visitors.head()
# Out:
#                         Park Name  Year  Visitors  Visitors Scaled Park_Code  \
# 1  Abraham Lincoln Birthplace NHP  1980  239074.0         0.010983      ABLI
# 2  Abraham Lincoln Birthplace NHP  1981  252245.0         0.011588      ABLI
# 3  Abraham Lincoln Birthplace NHP  1982  318707.0         0.014642      ABLI
# 4  Abraham Lincoln Birthplace NHP  1983  256126.0         0.011767      ABLI
# 5  Abraham Lincoln Birthplace NHP  1984  258023.0         0.011854      ABLI
#
#    Code_Year  site_chk  annual_chg  annual_chg_pct
# 1  ABLI-1980         1    -32157.0       -0.118559
# 2  ABLI-1981         1     13171.0        0.055092
# 3  ABLI-1982         1     66462.0        0.263482
# 4  ABLI-1983         1    -62581.0       -0.196359
# 5  ABLI-1984         1      1897.0        0.007407

# %%
visitors[visitors['Visitors']==0]
# Out:
#                                    Park Name  Year  Visitors  Visitors Scaled  \
# 492                      Aniakchak NM & PRES  1995       0.0              0.0
# 818         Arlington House The R.E. Lee MEM  2019       0.0              0.0
# 1028        Belmont-Paul Women's Equality NM  2021       0.0              0.0
# 2281                     Cape Krusenstern NM  2014       0.0              0.0
# 2543              Carter G. Woodson Home NHS  2021       0.0              0.0
# 3363                        Clara Barton NHS  2016       0.0              0.0
# 3368                        Clara Barton NHS  2021       0.0              0.0
# 4368                     Edgar Allan Poe NHS  2021       0.0              0.0
# 4372                     Edgar Allan Poe NHS  2025       0.0              0.0
# 4741                       Federal Hall NMEM  2005       0.0              0.0
# 7615                    Hamilton Grange NMEM  1980       0.0              0.0
# 7628                    Hamilton Grange NMEM  1993       0.0              0.0
# 7642                    Hamilton Grange NMEM  2007       0.0              0.0
# 7645                    Hamilton Grange NMEM  2010       0.0              0.0
# 8783                     John F. Kennedy NHS  2021       0.0              0.0
# 9045                        Katmai NP & PRES  1995       0.0              0.0
# 9460                         Kobuk Valley NP  2014       0.0              0.0
# 10216   Longfellow House Washington's HQ NHS  1999       0.0              0.0
# 10727  Mary McLeod Bethune Council House NHS  2021       0.0              0.0
# 11532        National Park of American Samoa  2003       0.0              0.0
# 11985                           Noatak NPRES  2014       0.0              0.0
# 12596                Pennsylvania Avenue NHS  2015       0.0              0.0
# 12602                Pennsylvania Avenue NHS  2021       0.0              0.0
# 14782                 Springfield Armory NHS  1988       0.0              0.0
# 14988                           Stonewall NM  2020       0.0              0.0
# 15122               Thaddeus Kosciuszko NMEM  2020       0.0              0.0
# 15341                      Thomas Edison NHP  2004       0.0              0.0
# 16330                    Washington Monument  2001       0.0              0.0
# 16341                    Washington Monument  2012       0.0              0.0
# 16346                    Washington Monument  2017       0.0              0.0
#
#       Park_Code  Code_Year  site_chk  annual_chg  annual_chg_pct
# 492        ANIA  ANIA-1995         1     -1193.0            -1.0
# 818        ARHO  ARHO-2019         1    -49500.0            -1.0
# 1028       BEPA  BEPA-2021         1     -2535.0            -1.0
# 2281       CAKR  CAKR-2014         1    -18225.0            -1.0
# 2543       CAWO  CAWO-2021         1      -548.0            -1.0
# 3363       CLBA  CLBA-2016         1     -2823.0            -1.0
# 3368       CLBA  CLBA-2021         1      -450.0            -1.0
# 4368       EDAL  EDAL-2021         1     -2418.0            -1.0
# 4372       EDAL  EDAL-2025         1     -8131.0            -1.0
# 4741       FEHA  FEHA-2005         1   -156707.0            -1.0
# 7615       HAGR  HAGR-1980         1      -371.0            -1.0
# 7628       HAGR  HAGR-1993         1    -13916.0            -1.0
# 7642       HAGR  HAGR-2007         1     -6369.0            -1.0
# 7645       HAGR  HAGR-2010         1      -150.0            -1.0
# 8783       JOFI  JOFI-2021         1      -451.0            -1.0
# 9045       KATM  KATM-1995         1    -55728.0            -1.0
# 9460       KOVA  KOVA-2014         1    -16875.0            -1.0
# 10216      LONG  LONG-1999         1    -19542.0            -1.0
# 10727      MAMC  MAMC-2021         1      -578.0            -1.0
# 11532      NPSA  NPSA-2003         1     -1938.0            -1.0
# 11985      NOAT  NOAT-2014         1    -16907.0            -1.0
# 12596      PAAV  PAAV-2015         1    -54035.0            -1.0
# 12602      PAAV  PAAV-2021         1    -15898.0            -1.0
# 14782      SPRA  SPRA-1988         1    -13705.0            -1.0
# 14988      STON  STON-2020         1  -2088929.0            -1.0
# 15122      THKO  THKO-2020         1     -1921.0            -1.0
# 15341      EDIS  EDIS-2004         1     -3359.0            -1.0
# 16330      WAMO  WAMO-2001         1   -185085.0            -1.0
# 16341      WAMO  WAMO-2012         1   -430153.0            -1.0
# 16346      WAMO  WAMO-2017         1   -252677.0            -1.0

# %%
# simplify data frame for merging
visitors_sel = visitors[['Park_Code','Code_Year','Year','Visitors','Visitors Scaled','annual_chg','annual_chg_pct']]
visitors_sel.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 1      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 2      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 3      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 4      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 5      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct
# 1       -0.118559
# 2        0.055092
# 3        0.263482
# 4       -0.196359
# 5        0.007407

# %%
high_vpct = visitors_sel[visitors_sel['annual_chg_pct'] > 10]

# %%
sns.scatterplot(data = high_vpct, x = 'Year', y = 'annual_chg_pct')
plt.show()

# %%
inf_chk0 = visitors[np.isinf(visitors['annual_chg_pct'])]
inf_chk0
# Out:
# Empty DataFrame
# Columns: [Park Name, Year, Visitors, Visitors Scaled, Park_Code, Code_Year, site_chk, annual_chg, annual_chg_pct]
# Index: []

# %%
# Add designation to data frame for additional filtering
# designation list
nps_sites_desiglist = nps_sites[['Park_Code','Designation']]

visitor_park_wdesig = pd.merge(visitor_park_abb,nps_sites_desiglist,on = 'Park_Code', how = 'left')

visitor_park_wdesig.drop(columns=['Park Name'], inplace=True)

visitor_park_wdesig.head()
# Out:
#   Park_Code               Designation
# 0      ABLI  National Historical Park
# 1      ACAD             National Park
# 2      ADAM  National Historical Park
# 3      AFBG         National Monument
# 4      AGFO         National Monument

# %% [markdown]
# #### National Park Service Traffic

# %%
# Traffic Data

traffic_file_1 = "Data/Query Builder for Traffic Counts (1985-1989).csv"

traffic_file_2 = "Data/Query Builder for Traffic Counts (1990-1999).csv"

traffic_file_3 = "Data/Query Builder for Traffic Counts (2000-2009).csv"

traffic_file_4 = "Data/Query Builder for Traffic Counts (2010-2019).csv"

traffic_file_5 = "Data/Query Builder for Traffic Counts (2020-2025).csv"

# %%
# Load traffic data
traffic_1_load = pd.read_csv(traffic_file_1)

#traffic_1_load.head(10)

traffic_1_load.columns = traffic_1_load.iloc[1]

traffic_1_load = traffic_1_load.iloc[2:].reset_index(drop = True)

traffic_1 = traffic_1_load[[]]

#traffic_1_load.head(10)

#traffic_1_load['Traffic Count'].dtype

traffic_1_load['Traffic Count'] = traffic_1_load['Traffic Count'].str.replace(",","")

#traffic_1_load.head()

traffic_1_load['Traffic Count'] = pd.to_numeric(traffic_1_load['Traffic Count'])

traffic_1_load['Unit Code'] = traffic_1_load['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})


#traffic_1_load['Traffic Count'].dtype

#traffic_1_load.head()

traffic_1 = traffic_1_load.groupby(['Unit Code','Year'])['Traffic Count'].sum().reset_index()

#traffic_1

#

traffic_2_load = pd.read_csv(traffic_file_2)

#traffic_2_load.head(10)

traffic_2_load.columns = traffic_2_load.iloc[1]

traffic_2_load = traffic_2_load.iloc[2:].reset_index(drop = True)

traffic_2 = traffic_2_load[[]]

#traffic_2_load.head(10)

#traffic_2_load['Traffic Count'].dtype

traffic_2_load['Traffic Count'] = traffic_2_load['Traffic Count'].str.replace(",","")

#traffic_2_load.head()

traffic_2_load['Traffic Count'] = pd.to_numeric(traffic_2_load['Traffic Count'])

traffic_2_load['Unit Code'] = traffic_2_load['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})


#traffic_2_load['Traffic Count'].dtype

#traffic_2_load.head()

traffic_2 = traffic_2_load.groupby(['Unit Code','Year'])['Traffic Count'].sum().reset_index()

#traffic_2

#

traffic_3_load = pd.read_csv(traffic_file_3)

#traffic_3_load.head(10)

traffic_3_load.columns = traffic_3_load.iloc[1]

traffic_3_load = traffic_3_load.iloc[2:].reset_index(drop = True)

traffic_3 = traffic_3_load[[]]

#traffic_3_load.head(10)

#traffic_3_load['Traffic Count'].dtype

traffic_3_load['Traffic Count'] = traffic_3_load['Traffic Count'].str.replace(",","")

#traffic_3_load.head()

traffic_3_load['Traffic Count'] = pd.to_numeric(traffic_3_load['Traffic Count'])

traffic_3_load['Unit Code'] = traffic_3_load['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})


#traffic_3_load['Traffic Count'].dtype

#traffic_3_load.head()

traffic_3 = traffic_3_load.groupby(['Unit Code','Year'])['Traffic Count'].sum().reset_index()

#traffic_3

#

traffic_4_load = pd.read_csv(traffic_file_4)

#traffic_4_load.head(10)

traffic_4_load.columns = traffic_4_load.iloc[1]

traffic_4_load = traffic_4_load.iloc[2:].reset_index(drop = True)

traffic_4 = traffic_4_load[[]]

#traffic_4_load.head(10)

#traffic_4_load['Traffic Count'].dtype

traffic_4_load['Traffic Count'] = traffic_4_load['Traffic Count'].str.replace(",","")

#traffic_4_load.head()

traffic_4_load['Traffic Count'] = pd.to_numeric(traffic_4_load['Traffic Count'])

traffic_4_load['Unit Code'] = traffic_4_load['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})


traffic_4_load['Traffic Count'].dtype

#traffic_4_load.head()

traffic_4 = traffic_4_load.groupby(['Unit Code','Year'])['Traffic Count'].sum().reset_index()

#traffic_4

#

traffic_5_load = pd.read_csv(traffic_file_5)

traffic_5_load.columns = traffic_5_load.iloc[1]

traffic_5_load = traffic_5_load.iloc[2:].reset_index(drop = True)

traffic_5 = traffic_5_load[[]]

traffic_5_load['Traffic Count'] = traffic_5_load['Traffic Count'].str.replace(",","")

#traffic_5_load.head()

traffic_5_load['Traffic Count'] = pd.to_numeric(traffic_5_load['Traffic Count'])

traffic_5_load['Unit Code'] = traffic_5_load['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})


traffic_5 = traffic_5_load.groupby(['Unit Code','Year'])['Traffic Count'].sum().reset_index()

# %%
# Concatenate Traffic Totals from Tables

traffic = pd.concat([traffic_1,traffic_2,traffic_3,traffic_4,traffic_5], ignore_index=True)

# %%
traffic.head()
# Out:
#   Unit Code  Year  Traffic Count
# 0      BLRI  1988      3721649.0
# 1      BLRI  1989      3891985.0
# 2      YOSE  1985      1571341.0
# 3      YOSE  1986      1370764.0
# 4      YOSE  1987      1621929.0

# %%
traffic['Year'] = pd.to_numeric(traffic['Year'])

#traffic['Unit Code'] = df['Unit Code'].replace({'FOCA': 'TIMU', 'JODR': 'GRTE', 'KICA': 'SEKI', 'SEQU': 'SEKI', 'NCPE': 'NACE', 'OBRI': 'OBED', 'ROLA':'NOCA'})

traffic['Code_Year'] = traffic['Unit Code'] + '-' + traffic['Year'].astype(str)

traffic_max = max(traffic['Traffic Count'])

traffic['Traffic Count Scaled'] = traffic['Traffic Count']/traffic_max

traffic = traffic.rename(columns={'Unit Code': 'Park_Code'})

traffic = traffic.sort_values(by='Code_Year')

print(traffic.head(10))

print(traffic.shape)
# Out:
#      Park_Code  Year  Traffic Count  Code_Year  Traffic Count Scaled
# 7         ABLI  1993        84248.0  ABLI-1993              0.002412
# 8         ABLI  1994        78659.0  ABLI-1994              0.002252
# 9         ABLI  1995        75253.0  ABLI-1995              0.002154
# 10        ABLI  1996        69894.0  ABLI-1996              0.002001
# 11        ABLI  1997        73586.0  ABLI-1997              0.002106
# 12        ABLI  1998        70560.0  ABLI-1998              0.002020
# 13        ABLI  1999        70798.0  ABLI-1999              0.002027
# 1414      ABLI  2000        67485.0  ABLI-2000              0.001932
# 1415      ABLI  2001        65934.0  ABLI-2001              0.001887
# 1416      ABLI  2002        94503.0  ABLI-2002              0.002705
# (6703, 5)

# %%
traffic.describe()
# Out:
#               Year  Traffic Count  Traffic Count Scaled
# count  6703.000000   6.703000e+03           6703.000000
# mean   2009.135611   9.601209e+05              0.027482
# std       9.757701   3.171714e+06              0.090787
# min    1985.000000  -2.633245e+06             -0.075374
# 25%    2001.000000   4.961450e+04              0.001420
# 50%    2009.000000   1.731410e+05              0.004956
# 75%    2018.000000   4.856385e+05              0.013901
# max    2025.000000   3.493576e+07              1.000000

# %%
traffic['Traffic Count'] = traffic['Traffic Count'].abs()
traffic['Traffic Count Scaled'] = traffic['Traffic Count Scaled'].abs()

# %%
traffic[traffic['Traffic Count'] < 0]
# Out:
# Empty DataFrame
# Columns: [Park_Code, Year, Traffic Count, Code_Year, Traffic Count Scaled]
# Index: []

# %%
traffic.describe()
# Out:
#               Year  Traffic Count  Traffic Count Scaled
# count  6703.000000   6.703000e+03           6703.000000
# mean   2009.135611   9.609398e+05              0.027506
# std       9.757701   3.171465e+06              0.090780
# min    1985.000000   0.000000e+00              0.000000
# 25%    2001.000000   4.967150e+04              0.001422
# 50%    2009.000000   1.731710e+05              0.004957
# 75%    2018.000000   4.859310e+05              0.013909
# max    2025.000000   3.493576e+07              1.000000

# %%
traffic.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6703 entries, 7 to 6702
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Park_Code             6703 non-null   str
#  1   Year                  6703 non-null   int64
#  2   Traffic Count         6703 non-null   float64
#  3   Code_Year             6703 non-null   str
#  4   Traffic Count Scaled  6703 non-null   float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 400.9 KB

# %%
# Calculate the change in annual visitor numbers from previous year 

# check to see if previous row is from same park
traffic['site_chk'] = (traffic['Park_Code'] == traffic['Park_Code'].shift(1)).astype(int)

# calculate the difference (whole and percentage) of visitors from the previous year (for the same site)
traffic['annual_chg'] = (traffic['Traffic Count'].diff()) * traffic['site_chk']
traffic['annual_chg_pct'] = (traffic['Traffic Count'].diff()) * traffic['site_chk'] / traffic['Traffic Count'].shift(1)

# replace infinite values with 15 
traffic['annual_chg_pct'] = traffic['annual_chg_pct'].replace(np.inf, 15)

# %%
traffic.head()
# Out:
#    Park_Code  Year  Traffic Count  Code_Year  Traffic Count Scaled  site_chk  \
# 7       ABLI  1993        84248.0  ABLI-1993              0.002412         0
# 8       ABLI  1994        78659.0  ABLI-1994              0.002252         1
# 9       ABLI  1995        75253.0  ABLI-1995              0.002154         1
# 10      ABLI  1996        69894.0  ABLI-1996              0.002001         1
# 11      ABLI  1997        73586.0  ABLI-1997              0.002106         1
#
#     annual_chg  annual_chg_pct
# 7          NaN             NaN
# 8      -5589.0       -0.066340
# 9      -3406.0       -0.043301
# 10     -5359.0       -0.071213
# 11      3692.0        0.052823

# %%
# remove the years with no previous year to track change
traffic = traffic[abs(traffic['annual_chg_pct']) > 0]
traffic.head()
# Out:
#    Park_Code  Year  Traffic Count  Code_Year  Traffic Count Scaled  site_chk  \
# 8       ABLI  1994        78659.0  ABLI-1994              0.002252         1
# 9       ABLI  1995        75253.0  ABLI-1995              0.002154         1
# 10      ABLI  1996        69894.0  ABLI-1996              0.002001         1
# 11      ABLI  1997        73586.0  ABLI-1997              0.002106         1
# 12      ABLI  1998        70560.0  ABLI-1998              0.002020         1
#
#     annual_chg  annual_chg_pct
# 8      -5589.0       -0.066340
# 9      -3406.0       -0.043301
# 10     -5359.0       -0.071213
# 11      3692.0        0.052823
# 12     -3026.0       -0.041122

# %%
traffic.describe()
# Out:
#               Year  Traffic Count  Traffic Count Scaled  site_chk  \
# count  6248.000000   6.248000e+03           6248.000000    6248.0
# mean   2009.722311   1.007596e+06              0.028841       1.0
# std       9.465440   3.262611e+06              0.093389       0.0
# min    1986.000000   0.000000e+00              0.000000       1.0
# 25%    2002.000000   5.627500e+04              0.001611       1.0
# 50%    2010.000000   1.871275e+05              0.005356       1.0
# 75%    2018.000000   5.073590e+05              0.014523       1.0
# max    2025.000000   3.493576e+07              1.000000       1.0
#
#          annual_chg  annual_chg_pct
# count  6.248000e+03     6248.000000
# mean   1.105406e+04        0.342127
# std    6.945586e+05       14.298497
# min   -2.837442e+07       -1.000000
# 25%   -1.074000e+04       -0.065520
# 50%    2.215000e+02        0.002507
# 75%    1.357525e+04        0.078164
# max    2.383250e+07     1114.500000

# %%
traffic_sel = traffic[['Park_Code','Code_Year','Year','Traffic Count','Traffic Count Scaled','annual_chg','annual_chg_pct']]

# %%
sns.scatterplot(data = traffic_sel, x = 'Year', y = 'annual_chg_pct')
plt.show()

# %% [markdown]
# #### National Park Site Area Data

# %%
# Load Nat'l Park Acreage Data

nps_area_file = "Data/NPS-Acreage-12-31-2025.csv"

nps_area_load = pd.read_csv(nps_area_file)

nps_area_load.head()

# Set first row to be header
nps_area_load.columns = nps_area_load.iloc[0]

nps_area_load = nps_area_load[1:].reset_index(drop = True)

nps_area_load['Gross Area Acres'] = pd.to_numeric(nps_area_load['Gross Area Acres'].str.replace(",",""))

# Remove notes from bottom of table
nps_area_load = nps_area_load.dropna(subset=['Region'])

# Downselect fields
nps_area = nps_area_load[['Area Name','Region','State','Gross Area Acres']]

# Scale area by max area value
#GAAmax = max(nps_area['Gross Area Acres'])

#nps_area['Gross Area Scaled'] = nps_area['Gross Area Acres']/GAAmax

nps_area.head(20)
# Out:
# 0                   Area Name Region        State  Gross Area Acres
# 0       A LINCOLN BIRTHPL NHP      1           KY            344.50
# 1                   ACADIA NP      1           ME          49076.65
# 2                   ADAMS NHP      1           MA             23.82
# 3    AFRICAN BURIAL GROUND NM      1           NY              0.35
# 4        AGATE FOSSIL BEDS NM      5           NE           3057.87
# 5            ALAGNAK WILD RVR     11           AK          30664.79
# 6   ALIBATES FLINT QUARRIES N      6           TX           1370.97
# 7      ALLEGHENY PRTGE RR NHS      1           PA           1284.27
# 8                  AMACHE NHS      7           CO            472.59
# 9                 AMISTAD NRA      6           TX          62945.15
# 10          ANDERSONVILLE NHS      2           GA            515.61
# 11         ANDREW JOHNSON NHS      2           TN             16.68
# 12       ANIAKCHAK N PRESERVE     11           AK         464117.93
# 13               ANIAKCHAK NM     11           AK         137176.00
# 14                ANTIETAM NB      1           MD           3287.63
# 15         APOSTLE ISLANDS NL      3           WI          69377.43
# 16       APPALACHIAN NS TRAIL   1, 2  ME TO GA 4/         244402.52
# 17      APPOMATTOX CRT HS NHP      1           VA           1774.60
# 18                  ARCHES NP      7           UT          76678.98
# 19         ARKANSAS POST NMEM      4           AR            757.51

# %%
# load area names to map to park codes for merging with other data
area_file_code = "Data/nps_area_list_codes.csv"

area_codes_load = pd.read_csv(area_file_code)
area_codes_load.head()

area_codes = area_codes_load[['Area Name','Park_Code']]

# %%
# attach park codes for further merging
nps_area = pd.merge(nps_area,area_codes,on = 'Area Name', how = 'left')

nps_area.head()
# Out:
#                   Area Name Region State  Gross Area Acres Park_Code
# 0     A LINCOLN BIRTHPL NHP      1    KY            344.50      ABLI
# 1                 ACADIA NP      1    ME          49076.65      ACAD
# 2                 ADAMS NHP      1    MA             23.82      ADAM
# 3  AFRICAN BURIAL GROUND NM      1    NY              0.35      AFBG
# 4      AGATE FOSSIL BEDS NM      5    NE           3057.87      AGFO

# %%
# remove unneeded fields
nps_area_red = nps_area[['Park_Code','Gross Area Acres']]

nps_area_red
# Out:
#     Park_Code  Gross Area Acres
# 0        ABLI            344.50
# 1        ACAD          49076.65
# 2        ADAM             23.82
# 3        AFBG              0.35
# 4        AGFO           3057.87
# ..        ...               ...
# 432      YELL        2219790.71
# 433      YOSE         761747.50
# 434      YUHO            195.07
# 435      YUCH        2526512.44
# 436      ZION         147242.66
#
# [437 rows x 2 columns]

# %% [markdown]
# ### Climate Data

# %%
# List of CE Regions and assigned states

cei_regions_file = "Data/CEI_Regions_States.csv"

cei_reg_load = pd.read_csv(cei_regions_file)

cei_reg_load.head(10)
# Out:
#                     CEI Region       State State Abb
# 0                    Northwest  Washington        WA
# 1                    Northwest      Oregon        OR
# 2                    Northwest       Idaho        ID
# 3                         West  California        CA
# 4                         West      Nevada        NV
# 5                    Southwest        Utah        UT
# 6                    Southwest    Colorado        CO
# 7                    Southwest     Arizona        AZ
# 8                    Southwest  New Mexico        NM
# 9  Northern Rockies and Plains     Montana        MT

# %%
cei_file_us = "Data/CEI_ContigUS.csv"

cei_us_load = pd.read_csv(cei_file_us)

cei_us_load.columns = cei_us_load.iloc[0]

cei_us_load = cei_us_load.iloc[1:].reset_index(drop = False)

cei_us_load = cei_us_load.rename(columns={'Date': '','index': 'Year'})

cei_us_load['Year'] = pd.to_numeric(cei_us_load['Year'])

cei_us_load['Percentage Area'] = pd.to_numeric(cei_us_load['Percentage Area'])/100

cei_us = cei_us_load

cei_us.head(10)
# Out:
# Date  Year  Percentage Area
# 0     1910           0.2292
# 1     1911           0.2416
# 2     1912           0.3592
# 3     1913           0.1926
# 4     1914           0.1990
# 5     1915           0.2138
# 6     1916           0.2898
# 7     1917           0.3394
# 8     1918           0.1168
# 9     1919           0.2014

# %%
# Set up US value to be used for the "Multiple" region

cei_mult = cei_us
cei_mult['Region'] = 'Multiple'
cei_mult
# Out:
# Date  Year  Percentage Area    Region
# 0     1910           0.2292  Multiple
# 1     1911           0.2416  Multiple
# 2     1912           0.3592  Multiple
# 3     1913           0.1926  Multiple
# 4     1914           0.1990  Multiple
# ..     ...              ...       ...
# 111   2021           0.3814  Multiple
# 112   2022           0.1758  Multiple
# 113   2023           0.3080  Multiple
# 114   2024           0.4590  Multiple
# 115   2025           0.3166  Multiple
#
# [116 rows x 3 columns]

# %%
cei_file_1 = "Data/CEI_Northwest.csv"

reg_name = "Northwest"

cei_1_load = pd.read_csv(cei_file_1)

cei_1_load.columns = cei_1_load.iloc[0]

cei_1_load = cei_1_load.iloc[1:].reset_index(drop = False)

cei_1_load = cei_1_load.rename(columns={'Date': '','index': 'Year'})

cei_1_load['Region'] = reg_name

#cei_1_load.head(10)

cei_file_2 = "Data/CEI_Southwest.csv"

reg_name = "Southwest"

cei_2_load = pd.read_csv(cei_file_2)

cei_2_load.columns = cei_2_load.iloc[0]

cei_2_load = cei_2_load.iloc[1:].reset_index(drop = False)

cei_2_load = cei_2_load.rename(columns={'Date': '','index': 'Year'})

cei_2_load['Region'] = reg_name

#cei_2_load.head(10)

cei_file_3 = "Data/CEI_South.csv"

reg_name = "South"

cei_3_load = pd.read_csv(cei_file_3)

cei_3_load.columns = cei_3_load.iloc[0]

cei_3_load = cei_3_load.iloc[1:].reset_index(drop = False)

cei_3_load = cei_3_load.rename(columns={'Date': '','index': 'Year'})

cei_3_load['Region'] = reg_name

#cei_3_load.head(10)

cei_file_4 = "Data/CEI_Northeast.csv"

reg_name = "Northeast"

cei_4_load = pd.read_csv(cei_file_4)

cei_4_load.columns = cei_4_load.iloc[0]

cei_4_load = cei_4_load.iloc[1:].reset_index(drop = False)

cei_4_load = cei_4_load.rename(columns={'Date': '','index': 'Year'})

cei_4_load['Region'] = reg_name

#cei_4_load.head(10)

cei_file_5 = "Data/CEI_NorthernRockiesandPlains.csv"

reg_name = "Northern Rockies and Plains"

cei_5_load = pd.read_csv(cei_file_5)

cei_5_load.columns = cei_5_load.iloc[0]

cei_5_load = cei_5_load.iloc[1:].reset_index(drop = False)

cei_5_load = cei_5_load.rename(columns={'Date': '','index': 'Year'})

cei_5_load['Region'] = reg_name

#cei_5_load.head(10)

cei_file_6 = "Data/CEI_OhioValley.csv"

reg_name = "Ohio Valley"

cei_6_load = pd.read_csv(cei_file_6)

cei_6_load.columns = cei_6_load.iloc[0]

cei_6_load = cei_6_load.iloc[1:].reset_index(drop = False)

cei_6_load = cei_6_load.rename(columns={'Date': '','index': 'Year'})

cei_6_load['Region'] = reg_name

#cei_6_load.head(10)

cei_file_7 = "Data/CEI_UpperMidwest.csv"

reg_name = "Upper Midwest"

cei_7_load = pd.read_csv(cei_file_7)

cei_7_load.columns = cei_7_load.iloc[0]

cei_7_load = cei_7_load.iloc[1:].reset_index(drop = False)

cei_7_load = cei_7_load.rename(columns={'Date': '','index': 'Year'})

cei_7_load['Region'] = reg_name

#cei_7_load.head(10)

cei_file_8 = "Data/CEI_Southeast.csv"

reg_name = "Southeast"

cei_8_load = pd.read_csv(cei_file_8)

cei_8_load.columns = cei_8_load.iloc[0]

cei_8_load = cei_8_load.iloc[1:].reset_index(drop = False)

cei_8_load = cei_8_load.rename(columns={'Date': '','index': 'Year'})

cei_8_load['Region'] = reg_name

#cei_8_load.head(10)

cei_file_9 = "Data/CEI_West.csv"

reg_name = "West"

cei_9_load = pd.read_csv(cei_file_9)

cei_9_load.columns = cei_9_load.iloc[0]

cei_9_load = cei_9_load.iloc[1:].reset_index(drop = False)

cei_9_load = cei_9_load.rename(columns={'Date': '','index': 'Year'})

cei_9_load['Region'] = reg_name

#cei_9_load.head(10)

# %%
# Concatenate CEI Data from Tables

cei_data = pd.concat([cei_1_load,cei_2_load,cei_3_load,cei_4_load,cei_5_load,cei_6_load,cei_7_load,cei_8_load,cei_9_load, cei_mult], ignore_index=True)

cei_data['Year'] = pd.to_numeric(cei_data['Year'])
cei_data['Percentage Area'] = pd.to_numeric(cei_data['Percentage Area'])/100

cei_data.head(10)

#print(cei_data.shape)
# Out:
# Date  Year  Percentage Area     Region
# 0     1910           0.1042  Northwest
# 1     1911           0.3650  Northwest
# 2     1912           0.3418  Northwest
# 3     1913           0.3692  Northwest
# 4     1914           0.0988  Northwest
# 5     1915           0.0390  Northwest
# 6     1916           0.5424  Northwest
# 7     1917           0.1802  Northwest
# 8     1918           0.0812  Northwest
# 9     1919           0.4144  Northwest

# %%
cei_data.tail(10)
# Out:
# Date  Year  Percentage Area    Region
# 1150  2016         0.004006  Multiple
# 1151  2017         0.003408  Multiple
# 1152  2018         0.002828  Multiple
# 1153  2019         0.002884  Multiple
# 1154  2020         0.003230  Multiple
# 1155  2021         0.003814  Multiple
# 1156  2022         0.001758  Multiple
# 1157  2023         0.003080  Multiple
# 1158  2024         0.004590  Multiple
# 1159  2025         0.003166  Multiple

# %% [markdown]
# ### El Nino Data

# %%
nino_file = "Data/ElNino_LaNina_Years_RONI.csv"

nino_load = pd.read_csv(nino_file)

# %%
nino_load.head()
# Out:
#    Year  RONI
# 0  1950  -1.5
# 1  1951  -0.5
# 2  1952   0.6
# 3  1953   0.5
# 4  1954   1.0

# %% [markdown]
# ### Combine Data Sets

# %% [markdown]
# #### Visitor Data

# %%
# base data frame
visitors_sel.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 1      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 2      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 3      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 4      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 5      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct
# 1       -0.118559
# 2        0.055092
# 3        0.263482
# 4       -0.196359
# 5        0.007407

# %%
# join base with site designation

df = pd.merge(visitors_sel, visitor_park_wdesig, on = 'Park_Code', how = 'left')
df.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 0      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 1      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 2      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 3      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 4      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct               Designation
# 0       -0.118559  National Historical Park
# 1        0.055092  National Historical Park
# 2        0.263482  National Historical Park
# 3       -0.196359  National Historical Park
# 4        0.007407  National Historical Park

# %%
# join with site area

df = pd.merge(df, nps_area_red, on = 'Park_Code', how = 'left')
df.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 0      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 1      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 2      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 3      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 4      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct               Designation  Gross Area Acres
# 0       -0.118559  National Historical Park             344.5
# 1        0.055092  National Historical Park             344.5
# 2        0.263482  National Historical Park             344.5
# 3       -0.196359  National Historical Park             344.5
# 4        0.007407  National Historical Park             344.5

# %%
# join site info with CEI regions 
nps_sites_2 = pd.merge(nps_sites, cei_reg_load, left_on = 'State List', right_on = 'State Abb', how = 'left')

nps_sites_2.loc[nps_sites_2['State List'] == 'DC', 'CEI Region'] = 'Southeast'

# CEI Regions are only for the contiguous US. Fill in categories for AK, HI and territories
nps_sites_2.loc[nps_sites_2['State List'] == 'AK', 'CEI Region'] = 'OCONUS'
nps_sites_2.loc[nps_sites_2['State List'] == 'HI', 'CEI Region'] = 'OCONUS'
nps_sites_2.loc[nps_sites_2['State List'] == 'MP', 'CEI Region'] = 'OCONUS-T'
nps_sites_2.loc[nps_sites_2['State List'] == 'PR', 'CEI Region'] = 'OCONUS-T'
nps_sites_2.loc[nps_sites_2['State List'] == 'VI', 'CEI Region'] = 'OCONUS-T'
nps_sites_2.loc[nps_sites_2['State List'] == 'GU', 'CEI Region'] = 'OCONUS-T'
nps_sites_2.loc[nps_sites_2['State List'] == 'AS', 'CEI Region'] = 'OCONUS-T'

nps_sites_2.head()
# Out:
#                                       Site_Full_Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#                     Site_Name Park_Code               Designation State List  \
# 0  Abraham Lincoln Birthplace      ABLI  National Historical Park         KY
# 1                      Acadia      ACAD             National Park         ME
# 2                       Adams      ADAM  National Historical Park         MA
# 3       African Burial Ground      AFBG         National Monument         NY
# 4           Agate Fossil Beds      AGFO         National Monument         NE
#
#                     CEI Region          State State Abb
# 0                  Ohio Valley       Kentucky        KY
# 1                    Northeast          Maine        ME
# 2                    Northeast  Massachusetts        MA
# 3                    Northeast       New York        NY
# 4  Northern Rockies and Plains       Nebraska        NE

# %%
# extract sites with regions not defined (not contiguous US or multiple states listed)
nps_sites_2bl = nps_sites_2[nps_sites_2['CEI Region'].isna()]

nps_sites_2bl
# Out:
#                                         Site_Full_Name  \
# 19                   Appalachian National Scenic Trail
# 23                 Assateague Island National Seashore
# 34     Big South Fork National River & Recreation Area
# 36             Bighorn Canyon National Recreation Area
# 40    Blackstone River Valley National Historical Park
# ..                                                 ...
# 412                   Vicksburg National Military Park
# 419  Washington-Rochambeau Revolutionary Route Nati...
# 433                          Yellowstone National Park
# 444                                     Chesapeake Bay
# 445                   Civil War Defenses of Washington
#
#                                      Site_Name Park_Code  \
# 19                                 Appalachian      APPA
# 23                           Assateague Island      ASIS
# 34                              Big South Fork      BISO
# 36                              Bighorn Canyon      BICA
# 40                     Blackstone River Valley      BLRV
# ..                                         ...       ...
# 412                                  Vicksburg      VICK
# 419  Washington-Rochambeau Revolutionary Route      WARO
# 433                                Yellowstone      YELL
# 444                             Chesapeake Bay      CBPO
# 445           Civil War Defenses of Washington      CWDW
#
#                           Designation  \
# 19              National Scenic Trail
# 23                  National Seashore
# 34   National River & Recreation Area
# 36           National Recreation Area
# 40           National Historical Park
# ..                                ...
# 412            National Military Park
# 419           National Historic Trail
# 433                     National Park
# 444                      Undesignated
# 445                      Undesignated
#
#                                     State List CEI Region State State Abb
# 19   CT,GA,MA,MD,ME,NC,NH,NJ,NY,PA,TN,VA,VT,WV        NaN   NaN       NaN
# 23                                       MD,VA        NaN   NaN       NaN
# 34                                       KY,TN        NaN   NaN       NaN
# 36                                       MT,WY        NaN   NaN       NaN
# 40                                       RI,MA        NaN   NaN       NaN
# ..                                         ...        ...   ...       ...
# 412                                      MS,LA        NaN   NaN       NaN
# 419              MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC        NaN   NaN       NaN
# 433                                   ID,MT,WY        NaN   NaN       NaN
# 444                       DC,DE,MD,NY,PA,VA,WV        NaN   NaN       NaN
# 445                                   DC,MD,VA        NaN   NaN       NaN
#
# [62 rows x 8 columns]

# %%
# Tag sites with multiple states as "Multiple"
nps_sites_2bl['State'] = 'Multiple'
nps_sites_2bl['State Abb'] = 'ML'
nps_sites_2bl = nps_sites_2bl.drop(columns = ['CEI Region'])
nps_sites_2bl
# Out:
#                                         Site_Full_Name  \
# 19                   Appalachian National Scenic Trail
# 23                 Assateague Island National Seashore
# 34     Big South Fork National River & Recreation Area
# 36             Bighorn Canyon National Recreation Area
# 40    Blackstone River Valley National Historical Park
# ..                                                 ...
# 412                   Vicksburg National Military Park
# 419  Washington-Rochambeau Revolutionary Route Nati...
# 433                          Yellowstone National Park
# 444                                     Chesapeake Bay
# 445                   Civil War Defenses of Washington
#
#                                      Site_Name Park_Code  \
# 19                                 Appalachian      APPA
# 23                           Assateague Island      ASIS
# 34                              Big South Fork      BISO
# 36                              Bighorn Canyon      BICA
# 40                     Blackstone River Valley      BLRV
# ..                                         ...       ...
# 412                                  Vicksburg      VICK
# 419  Washington-Rochambeau Revolutionary Route      WARO
# 433                                Yellowstone      YELL
# 444                             Chesapeake Bay      CBPO
# 445           Civil War Defenses of Washington      CWDW
#
#                           Designation  \
# 19              National Scenic Trail
# 23                  National Seashore
# 34   National River & Recreation Area
# 36           National Recreation Area
# 40           National Historical Park
# ..                                ...
# 412            National Military Park
# 419           National Historic Trail
# 433                     National Park
# 444                      Undesignated
# 445                      Undesignated
#
#                                     State List     State State Abb
# 19   CT,GA,MA,MD,ME,NC,NH,NJ,NY,PA,TN,VA,VT,WV  Multiple        ML
# 23                                       MD,VA  Multiple        ML
# 34                                       KY,TN  Multiple        ML
# 36                                       MT,WY  Multiple        ML
# 40                                       RI,MA  Multiple        ML
# ..                                         ...       ...       ...
# 412                                      MS,LA  Multiple        ML
# 419              MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC  Multiple        ML
# 433                                   ID,MT,WY  Multiple        ML
# 444                       DC,DE,MD,NY,PA,VA,WV  Multiple        ML
# 445                                   DC,MD,VA  Multiple        ML
#
# [62 rows x 7 columns]

# %%
# Upload manually generated list to assign regions to state groups 
states_region_load = "Data/state_combo_list_key.csv"

state_region = pd.read_csv(states_region_load)

# %%
# join region info to site info
nps_sites_2blm = pd.merge(nps_sites_2bl, state_region, on = 'State List')

# %%
nps_sites_2blm
# Out:
#                                        Site_Full_Name  \
# 0                   Appalachian National Scenic Trail
# 1                 Assateague Island National Seashore
# 2     Big South Fork National River & Recreation Area
# 3             Bighorn Canyon National Recreation Area
# 4    Blackstone River Valley National Historical Park
# ..                                                ...
# 57                   Vicksburg National Military Park
# 58  Washington-Rochambeau Revolutionary Route Nati...
# 59                          Yellowstone National Park
# 60                                     Chesapeake Bay
# 61                   Civil War Defenses of Washington
#
#                                     Site_Name Park_Code  \
# 0                                 Appalachian      APPA
# 1                           Assateague Island      ASIS
# 2                              Big South Fork      BISO
# 3                              Bighorn Canyon      BICA
# 4                     Blackstone River Valley      BLRV
# ..                                        ...       ...
# 57                                  Vicksburg      VICK
# 58  Washington-Rochambeau Revolutionary Route      WARO
# 59                                Yellowstone      YELL
# 60                             Chesapeake Bay      CBPO
# 61           Civil War Defenses of Washington      CWDW
#
#                          Designation  \
# 0              National Scenic Trail
# 1                  National Seashore
# 2   National River & Recreation Area
# 3           National Recreation Area
# 4           National Historical Park
# ..                               ...
# 57            National Military Park
# 58           National Historic Trail
# 59                     National Park
# 60                      Undesignated
# 61                      Undesignated
#
#                                    State List     State State Abb  \
# 0   CT,GA,MA,MD,ME,NC,NH,NJ,NY,PA,TN,VA,VT,WV  Multiple        ML
# 1                                       MD,VA  Multiple        ML
# 2                                       KY,TN  Multiple        ML
# 3                                       MT,WY  Multiple        ML
# 4                                       RI,MA  Multiple        ML
# ..                                        ...       ...       ...
# 57                                      MS,LA  Multiple        ML
# 58              MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC  Multiple        ML
# 59                                   ID,MT,WY  Multiple        ML
# 60                       DC,DE,MD,NY,PA,VA,WV  Multiple        ML
# 61                                   DC,MD,VA  Multiple        ML
#
#                      CEI Region
# 0                      Multiple
# 1                      Multiple
# 2                   Ohio Valley
# 3   Northern Rockies and Plains
# 4                     Northeast
# ..                          ...
# 57                        South
# 58                     Multiple
# 59                     Multiple
# 60                     Multiple
# 61                     Multiple
#
# [62 rows x 8 columns]

# %%
# extract sites with regions defined
nps_sites_2fl = nps_sites_2[nps_sites_2['CEI Region'].notna()]

nps_sites_2fl
# Out:
#                                         Site_Full_Name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 3              African Burial Ground National Monument
# 4                  Agate Fossil Beds National Monument
# ..                                                 ...
# 469                          Vietnam Veterans Memorial
# 470                                Washington Monument
# 471    Wolf Trap National Park for the Performing Arts
# 472                               World War I Memorial
# 473                              World War II Memorial
#
#                                            Site_Name Park_Code  \
# 0                         Abraham Lincoln Birthplace      ABLI
# 1                                             Acadia      ACAD
# 2                                              Adams      ADAM
# 3                              African Burial Ground      AFBG
# 4                                  Agate Fossil Beds      AGFO
# ..                                               ...       ...
# 469                        Vietnam Veterans Memorial      VIVE
# 470                              Washington Monument      WAMO
# 471  Wolf Trap National Park for the Performing Arts      WOTR
# 472                             World War I Memorial      WWIM
# 473                            World War II Memorial      WWII
#
#                   Designation State List                   CEI Region  \
# 0    National Historical Park         KY                  Ohio Valley
# 1               National Park         ME                    Northeast
# 2    National Historical Park         MA                    Northeast
# 3           National Monument         NY                    Northeast
# 4           National Monument         NE  Northern Rockies and Plains
# ..                        ...        ...                          ...
# 469              Undesignated         DC                    Southeast
# 470              Undesignated         DC                    Southeast
# 471              Undesignated         VA                    Southeast
# 472              Undesignated         DC                    Southeast
# 473              Undesignated         DC                    Southeast
#
#              State State Abb
# 0         Kentucky        KY
# 1            Maine        ME
# 2    Massachusetts        MA
# 3         New York        NY
# 4         Nebraska        NE
# ..             ...       ...
# 469            NaN       NaN
# 470            NaN       NaN
# 471       Virginia        VA
# 472            NaN       NaN
# 473            NaN       NaN
#
# [412 rows x 8 columns]

# %%
# recombine tables to have the full set with regions defined for all sites
nps_sites_m = pd.concat([nps_sites_2fl, nps_sites_2blm], ignore_index = True)
nps_sites_m = nps_sites_m.sort_values(by = 'Park_Code')
nps_sites_m = nps_sites_m.drop(columns = ['State', 'State Abb'])
nps_sites_m
# Out:
#                                         Site_Full_Name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 379                African American Civil War Memorial
# 3              African Burial Ground National Monument
# ..                                                 ...
# 374  Yorktown Battlefield Part of Colonial National...
# 375                             Yosemite National Park
# 377           Yukon - Charley Rivers National Preserve
# 376                      Yucca House National Monument
# 378                                 Zion National Park
#
#                                Site_Name Park_Code  \
# 0             Abraham Lincoln Birthplace      ABLI
# 1                                 Acadia      ACAD
# 2                                  Adams      ADAM
# 379  African American Civil War Memorial      AFAM
# 3                  African Burial Ground      AFBG
# ..                                   ...       ...
# 374                 Yorktown Battlefield      YORK
# 375                             Yosemite      YOSE
# 377               Yukon - Charley Rivers      YUCH
# 376                          Yucca House      YUHO
# 378                                 Zion      ZION
#
#                                    Designation State List   CEI Region
# 0                     National Historical Park         KY  Ohio Valley
# 1                                National Park         ME    Northeast
# 2                     National Historical Park         MA    Northeast
# 379                               Undesignated         DC    Southeast
# 3                            National Monument         NY    Northeast
# ..                                         ...        ...          ...
# 374  Part of Colonial National Historical Park         VA    Southeast
# 375                              National Park         CA         West
# 377                          National Preserve         AK       OCONUS
# 376                          National Monument         CO    Southwest
# 378                              National Park         UT    Southwest
#
# [474 rows x 6 columns]

# %%
# merge data tables to create site data table for analysis
nps_next = pd.merge(df,nps_sites_m, on = 'Park_Code', how = 'left')
nps_next
# Out:
#       Park_Code  Code_Year  Year   Visitors  Visitors Scaled  annual_chg  \
# 0          ABLI  ABLI-1980  1980   239074.0         0.010983    -32157.0
# 1          ABLI  ABLI-1981  1981   252245.0         0.011588     13171.0
# 2          ABLI  ABLI-1982  1982   318707.0         0.014642     66462.0
# 3          ABLI  ABLI-1983  1983   256126.0         0.011767    -62581.0
# 4          ABLI  ABLI-1984  1984   258023.0         0.011854      1897.0
# ...         ...        ...   ...        ...              ...         ...
# 17931      ZION  ZION-2021  2021  5039835.0         0.231534   1448581.0
# 17932      ZION  ZION-2022  2022  4692417.0         0.215573   -347418.0
# 17933      ZION  ZION-2023  2023  4623238.0         0.212395    -69179.0
# 17934      ZION  ZION-2024  2024  4946592.0         0.227250    323354.0
# 17935      ZION  ZION-2025  2025  4984525.0         0.228993     37933.0
#
#        annual_chg_pct             Designation_x  Gross Area Acres  \
# 0           -0.118559  National Historical Park            344.50
# 1            0.055092  National Historical Park            344.50
# 2            0.263482  National Historical Park            344.50
# 3           -0.196359  National Historical Park            344.50
# 4            0.007407  National Historical Park            344.50
# ...               ...                       ...               ...
# 17931        0.403364             National Park         147242.66
# 17932       -0.068934             National Park         147242.66
# 17933       -0.014743             National Park         147242.66
# 17934        0.069941             National Park         147242.66
# 17935        0.007669             National Park         147242.66
#
#                                           Site_Full_Name  \
# 0      Abraham Lincoln Birthplace National Historical...
# 1      Abraham Lincoln Birthplace National Historical...
# 2      Abraham Lincoln Birthplace National Historical...
# 3      Abraham Lincoln Birthplace National Historical...
# 4      Abraham Lincoln Birthplace National Historical...
# ...                                                  ...
# 17931                                 Zion National Park
# 17932                                 Zion National Park
# 17933                                 Zion National Park
# 17934                                 Zion National Park
# 17935                                 Zion National Park
#
#                         Site_Name             Designation_y State List  \
# 0      Abraham Lincoln Birthplace  National Historical Park         KY
# 1      Abraham Lincoln Birthplace  National Historical Park         KY
# 2      Abraham Lincoln Birthplace  National Historical Park         KY
# 3      Abraham Lincoln Birthplace  National Historical Park         KY
# 4      Abraham Lincoln Birthplace  National Historical Park         KY
# ...                           ...                       ...        ...
# 17931                        Zion             National Park         UT
# 17932                        Zion             National Park         UT
# 17933                        Zion             National Park         UT
# 17934                        Zion             National Park         UT
# 17935                        Zion             National Park         UT
#
#         CEI Region
# 0      Ohio Valley
# 1      Ohio Valley
# 2      Ohio Valley
# 3      Ohio Valley
# 4      Ohio Valley
# ...            ...
# 17931    Southwest
# 17932    Southwest
# 17933    Southwest
# 17934    Southwest
# 17935    Southwest
#
# [17936 rows x 14 columns]

# %%
nps_sites_m
# Out:
#                                         Site_Full_Name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 379                African American Civil War Memorial
# 3              African Burial Ground National Monument
# ..                                                 ...
# 374  Yorktown Battlefield Part of Colonial National...
# 375                             Yosemite National Park
# 377           Yukon - Charley Rivers National Preserve
# 376                      Yucca House National Monument
# 378                                 Zion National Park
#
#                                Site_Name Park_Code  \
# 0             Abraham Lincoln Birthplace      ABLI
# 1                                 Acadia      ACAD
# 2                                  Adams      ADAM
# 379  African American Civil War Memorial      AFAM
# 3                  African Burial Ground      AFBG
# ..                                   ...       ...
# 374                 Yorktown Battlefield      YORK
# 375                             Yosemite      YOSE
# 377               Yukon - Charley Rivers      YUCH
# 376                          Yucca House      YUHO
# 378                                 Zion      ZION
#
#                                    Designation State List   CEI Region
# 0                     National Historical Park         KY  Ohio Valley
# 1                                National Park         ME    Northeast
# 2                     National Historical Park         MA    Northeast
# 379                               Undesignated         DC    Southeast
# 3                            National Monument         NY    Northeast
# ..                                         ...        ...          ...
# 374  Part of Colonial National Historical Park         VA    Southeast
# 375                              National Park         CA         West
# 377                          National Preserve         AK       OCONUS
# 376                          National Monument         CO    Southwest
# 378                              National Park         UT    Southwest
#
# [474 rows x 6 columns]

# %%
# select components 
nps_cei_regions = nps_sites_m[['Park_Code','CEI Region']]
nps_cei_regions
# Out:
#     Park_Code   CEI Region
# 0        ABLI  Ohio Valley
# 1        ACAD    Northeast
# 2        ADAM    Northeast
# 379      AFAM    Southeast
# 3        AFBG    Northeast
# ..        ...          ...
# 374      YORK    Southeast
# 375      YOSE         West
# 377      YUCH       OCONUS
# 376      YUHO    Southwest
# 378      ZION    Southwest
#
# [474 rows x 2 columns]

# %%
# remove rows in OCONUS Regions (no CEI data)
nps_regions = nps_cei_regions[(nps_cei_regions['CEI Region']!='OCONUS') & (nps_cei_regions['CEI Region']!='OCONUS-T')  ]

nps_regions.rename(columns={"CEI Region": "Region"}, inplace=True)

nps_regions
# Out:
#     Park_Code       Region
# 0        ABLI  Ohio Valley
# 1        ACAD    Northeast
# 2        ADAM    Northeast
# 379      AFAM    Southeast
# 3        AFBG    Northeast
# ..        ...          ...
# 471      YELL     Multiple
# 374      YORK    Southeast
# 375      YOSE         West
# 376      YUHO    Southwest
# 378      ZION    Southwest
#
# [437 rows x 2 columns]

# %%
df.shape
# Out:
# (17936, 9)

# %%
df['Park_Code'].nunique()
# Out:
# 392

# %%
nps_regions['Park_Code'].nunique()
# Out:
# 437

# %%
# check for common park codes between the data sets

df['Park_Code'].isin(nps_regions['Park_Code']).sum()
# Out:
# np.int64(16490)

# %%
nps_regions['Park_Code'].isin(df['Park_Code']).sum()
# Out:
# np.int64(362)

# %%
df1 = pd.merge(df, nps_regions, on = 'Park_Code', how = 'left')

# %%
nino_load.head()
# Out:
#    Year  RONI
# 0  1950  -1.5
# 1  1951  -0.5
# 2  1952   0.6
# 3  1953   0.5
# 4  1954   1.0

# %%
df1 = pd.merge(df1, nino_load, on = 'Year', how = 'left')
df1.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 0      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 1      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 2      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 3      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 4      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct               Designation  Gross Area Acres       Region  \
# 0       -0.118559  National Historical Park             344.5  Ohio Valley
# 1        0.055092  National Historical Park             344.5  Ohio Valley
# 2        0.263482  National Historical Park             344.5  Ohio Valley
# 3       -0.196359  National Historical Park             344.5  Ohio Valley
# 4        0.007407  National Historical Park             344.5  Ohio Valley
#
#    RONI
# 0   0.6
# 1   0.0
# 2   0.1
# 3   2.5
# 4  -0.5

# %%
# Add composite feature to be able to join nps data with cei data

df1['Region-Year'] = df1['Region'] + '-' + df1['Year'].astype(str)
df1.head()
# Out:
#   Park_Code  Code_Year  Year  Visitors  Visitors Scaled  annual_chg  \
# 0      ABLI  ABLI-1980  1980  239074.0         0.010983    -32157.0
# 1      ABLI  ABLI-1981  1981  252245.0         0.011588     13171.0
# 2      ABLI  ABLI-1982  1982  318707.0         0.014642     66462.0
# 3      ABLI  ABLI-1983  1983  256126.0         0.011767    -62581.0
# 4      ABLI  ABLI-1984  1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct               Designation  Gross Area Acres       Region  \
# 0       -0.118559  National Historical Park             344.5  Ohio Valley
# 1        0.055092  National Historical Park             344.5  Ohio Valley
# 2        0.263482  National Historical Park             344.5  Ohio Valley
# 3       -0.196359  National Historical Park             344.5  Ohio Valley
# 4        0.007407  National Historical Park             344.5  Ohio Valley
#
#    RONI       Region-Year
# 0   0.6  Ohio Valley-1980
# 1   0.0  Ohio Valley-1981
# 2   0.1  Ohio Valley-1982
# 3   2.5  Ohio Valley-1983
# 4  -0.5  Ohio Valley-1984

# %%
# add same composite feature to CEI data
cei_data['Region-Year'] = cei_data['Region'] + '-' + cei_data['Year'].astype(str)
cei_data.head()
# Out:
# Date  Year  Percentage Area     Region     Region-Year
# 0     1910           0.1042  Northwest  Northwest-1910
# 1     1911           0.3650  Northwest  Northwest-1911
# 2     1912           0.3418  Northwest  Northwest-1912
# 3     1913           0.3692  Northwest  Northwest-1913
# 4     1914           0.0988  Northwest  Northwest-1914

# %%
df2 = pd.merge(df1, cei_data, on = 'Region-Year', how = 'left')
df2.head()
# Out:
#   Park_Code  Code_Year  Year_x  Visitors  Visitors Scaled  annual_chg  \
# 0      ABLI  ABLI-1980    1980  239074.0         0.010983    -32157.0
# 1      ABLI  ABLI-1981    1981  252245.0         0.011588     13171.0
# 2      ABLI  ABLI-1982    1982  318707.0         0.014642     66462.0
# 3      ABLI  ABLI-1983    1983  256126.0         0.011767    -62581.0
# 4      ABLI  ABLI-1984    1984  258023.0         0.011854      1897.0
#
#    annual_chg_pct               Designation  Gross Area Acres     Region_x  \
# 0       -0.118559  National Historical Park             344.5  Ohio Valley
# 1        0.055092  National Historical Park             344.5  Ohio Valley
# 2        0.263482  National Historical Park             344.5  Ohio Valley
# 3       -0.196359  National Historical Park             344.5  Ohio Valley
# 4        0.007407  National Historical Park             344.5  Ohio Valley
#
#    RONI       Region-Year  Year_y  Percentage Area     Region_y
# 0   0.6  Ohio Valley-1980  1980.0           0.1162  Ohio Valley
# 1   0.0  Ohio Valley-1981  1981.0           0.1120  Ohio Valley
# 2   0.1  Ohio Valley-1982  1982.0           0.1230  Ohio Valley
# 3   2.5  Ohio Valley-1983  1983.0           0.0882  Ohio Valley
# 4  -0.5  Ohio Valley-1984  1984.0           0.0780  Ohio Valley

# %%
# clean up data frame

df3 = df2[['Code_Year','Visitors','Visitors Scaled','annual_chg','annual_chg_pct','Designation','Gross Area Acres','Region_x','Percentage Area','RONI']]
df3.rename(columns={"annual_chg": "vis_annual_chg", "annual_chg_pct": "vis_annual_chg_pct", "Region_x": "Region",'Percentage Area':'cei_pct_area'}, inplace=True)
df3.head()
# Out:
#    Code_Year  Visitors  Visitors Scaled  vis_annual_chg  vis_annual_chg_pct  \
# 0  ABLI-1980  239074.0         0.010983        -32157.0           -0.118559
# 1  ABLI-1981  252245.0         0.011588         13171.0            0.055092
# 2  ABLI-1982  318707.0         0.014642         66462.0            0.263482
# 3  ABLI-1983  256126.0         0.011767        -62581.0           -0.196359
# 4  ABLI-1984  258023.0         0.011854          1897.0            0.007407
#
#                 Designation  Gross Area Acres       Region  cei_pct_area  RONI
# 0  National Historical Park             344.5  Ohio Valley        0.1162   0.6
# 1  National Historical Park             344.5  Ohio Valley        0.1120   0.0
# 2  National Historical Park             344.5  Ohio Valley        0.1230   0.1
# 3  National Historical Park             344.5  Ohio Valley        0.0882   2.5
# 4  National Historical Park             344.5  Ohio Valley        0.0780  -0.5

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17936 entries, 0 to 17935
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Code_Year           17936 non-null  str
#  1   Visitors            17936 non-null  float64
#  2   Visitors Scaled     17936 non-null  float64
#  3   vis_annual_chg      17936 non-null  float64
#  4   vis_annual_chg_pct  17936 non-null  float64
#  5   Designation         17936 non-null  str
#  6   Gross Area Acres    17936 non-null  float64
#  7   Region              16490 non-null  str
#  8   cei_pct_area        16490 non-null  float64
#  9   RONI                17936 non-null  float64
# dtypes: float64(7), str(3)
# memory usage: 2.0 MB

# %%
df3 = df3[df3['Region'].notna()]
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16490 entries, 0 to 17935
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Code_Year           16490 non-null  str
#  1   Visitors            16490 non-null  float64
#  2   Visitors Scaled     16490 non-null  float64
#  3   vis_annual_chg      16490 non-null  float64
#  4   vis_annual_chg_pct  16490 non-null  float64
#  5   Designation         16490 non-null  str
#  6   Gross Area Acres    16490 non-null  float64
#  7   Region              16490 non-null  str
#  8   cei_pct_area        16490 non-null  float64
#  9   RONI                16490 non-null  float64
# dtypes: float64(7), str(3)
# memory usage: 2.0 MB

# %% [markdown]
# #### Traffic Data

# %%
# base data frame
traffic_sel.head()
# Out:
#    Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  \
# 8       ABLI  ABLI-1994  1994        78659.0              0.002252
# 9       ABLI  ABLI-1995  1995        75253.0              0.002154
# 10      ABLI  ABLI-1996  1996        69894.0              0.002001
# 11      ABLI  ABLI-1997  1997        73586.0              0.002106
# 12      ABLI  ABLI-1998  1998        70560.0              0.002020
#
#     annual_chg  annual_chg_pct
# 8      -5589.0       -0.066340
# 9      -3406.0       -0.043301
# 10     -5359.0       -0.071213
# 11      3692.0        0.052823
# 12     -3026.0       -0.041122

# %%
visitor_park_wdesig
# Out:
#     Park_Code               Designation
# 0        ABLI  National Historical Park
# 1        ACAD             National Park
# 2        ADAM  National Historical Park
# 3        AFBG         National Monument
# 4        AGFO         National Monument
# ..        ...                       ...
# 395      WUPA         National Monument
# 396      YELL             National Park
# 397      YOSE             National Park
# 398      YUCH         National Preserve
# 399      ZION             National Park
#
# [400 rows x 2 columns]

# %%
# join base with site designation

df_t = pd.merge(traffic_sel, nps_sites, on = 'Park_Code', how = 'left')
df_t.head()
# Out:
#   Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  annual_chg  \
# 0      ABLI  ABLI-1994  1994        78659.0              0.002252     -5589.0
# 1      ABLI  ABLI-1995  1995        75253.0              0.002154     -3406.0
# 2      ABLI  ABLI-1996  1996        69894.0              0.002001     -5359.0
# 3      ABLI  ABLI-1997  1997        73586.0              0.002106      3692.0
# 4      ABLI  ABLI-1998  1998        70560.0              0.002020     -3026.0
#
#    annual_chg_pct                                     Site_Full_Name  \
# 0       -0.066340  Abraham Lincoln Birthplace National Historical...
# 1       -0.043301  Abraham Lincoln Birthplace National Historical...
# 2       -0.071213  Abraham Lincoln Birthplace National Historical...
# 3        0.052823  Abraham Lincoln Birthplace National Historical...
# 4       -0.041122  Abraham Lincoln Birthplace National Historical...
#
#                     Site_Name               Designation State List
# 0  Abraham Lincoln Birthplace  National Historical Park         KY
# 1  Abraham Lincoln Birthplace  National Historical Park         KY
# 2  Abraham Lincoln Birthplace  National Historical Park         KY
# 3  Abraham Lincoln Birthplace  National Historical Park         KY
# 4  Abraham Lincoln Birthplace  National Historical Park         KY

# %%
# join with site area

df_t = pd.merge(df_t, nps_area_red, on = 'Park_Code', how = 'left')
df_t.head()
# Out:
#   Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  annual_chg  \
# 0      ABLI  ABLI-1994  1994        78659.0              0.002252     -5589.0
# 1      ABLI  ABLI-1995  1995        75253.0              0.002154     -3406.0
# 2      ABLI  ABLI-1996  1996        69894.0              0.002001     -5359.0
# 3      ABLI  ABLI-1997  1997        73586.0              0.002106      3692.0
# 4      ABLI  ABLI-1998  1998        70560.0              0.002020     -3026.0
#
#    annual_chg_pct                                     Site_Full_Name  \
# 0       -0.066340  Abraham Lincoln Birthplace National Historical...
# 1       -0.043301  Abraham Lincoln Birthplace National Historical...
# 2       -0.071213  Abraham Lincoln Birthplace National Historical...
# 3        0.052823  Abraham Lincoln Birthplace National Historical...
# 4       -0.041122  Abraham Lincoln Birthplace National Historical...
#
#                     Site_Name               Designation State List  \
# 0  Abraham Lincoln Birthplace  National Historical Park         KY
# 1  Abraham Lincoln Birthplace  National Historical Park         KY
# 2  Abraham Lincoln Birthplace  National Historical Park         KY
# 3  Abraham Lincoln Birthplace  National Historical Park         KY
# 4  Abraham Lincoln Birthplace  National Historical Park         KY
#
#    Gross Area Acres
# 0             344.5
# 1             344.5
# 2             344.5
# 3             344.5
# 4             344.5

# %%
# merge data tables to create site data table for analysis
nps_next_t = pd.merge(df_t,nps_sites_m, on = 'Park_Code', how = 'left')
nps_next_t
# Out:
#      Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  \
# 0         ABLI  ABLI-1994  1994        78659.0              0.002252
# 1         ABLI  ABLI-1995  1995        75253.0              0.002154
# 2         ABLI  ABLI-1996  1996        69894.0              0.002001
# 3         ABLI  ABLI-1997  1997        73586.0              0.002106
# 4         ABLI  ABLI-1998  1998        70560.0              0.002020
# ...        ...        ...   ...            ...                   ...
# 6549      ZION  ZION-2021  2021      1550770.0              0.044389
# 6550      ZION  ZION-2022  2022      1416308.0              0.040540
# 6551      ZION  ZION-2023  2023      1410960.0              0.040387
# 6552      ZION  ZION-2024  2024      1470401.0              0.042089
# 6553      ZION  ZION-2025  2025      1491553.0              0.042694
#
#       annual_chg  annual_chg_pct  \
# 0        -5589.0       -0.066340
# 1        -3406.0       -0.043301
# 2        -5359.0       -0.071213
# 3         3692.0        0.052823
# 4        -3026.0       -0.041122
# ...          ...             ...
# 6549    323846.0        0.263950
# 6550   -134462.0       -0.086707
# 6551     -5348.0       -0.003776
# 6552     59441.0        0.042128
# 6553     21152.0        0.014385
#
#                                        Site_Full_Name_x  \
# 0     Abraham Lincoln Birthplace National Historical...
# 1     Abraham Lincoln Birthplace National Historical...
# 2     Abraham Lincoln Birthplace National Historical...
# 3     Abraham Lincoln Birthplace National Historical...
# 4     Abraham Lincoln Birthplace National Historical...
# ...                                                 ...
# 6549                                 Zion National Park
# 6550                                 Zion National Park
# 6551                                 Zion National Park
# 6552                                 Zion National Park
# 6553                                 Zion National Park
#
#                      Site_Name_x             Designation_x State List_x  \
# 0     Abraham Lincoln Birthplace  National Historical Park           KY
# 1     Abraham Lincoln Birthplace  National Historical Park           KY
# 2     Abraham Lincoln Birthplace  National Historical Park           KY
# 3     Abraham Lincoln Birthplace  National Historical Park           KY
# 4     Abraham Lincoln Birthplace  National Historical Park           KY
# ...                          ...                       ...          ...
# 6549                        Zion             National Park           UT
# 6550                        Zion             National Park           UT
# 6551                        Zion             National Park           UT
# 6552                        Zion             National Park           UT
# 6553                        Zion             National Park           UT
#
#       Gross Area Acres                                   Site_Full_Name_y  \
# 0               344.50  Abraham Lincoln Birthplace National Historical...
# 1               344.50  Abraham Lincoln Birthplace National Historical...
# 2               344.50  Abraham Lincoln Birthplace National Historical...
# 3               344.50  Abraham Lincoln Birthplace National Historical...
# 4               344.50  Abraham Lincoln Birthplace National Historical...
# ...                ...                                                ...
# 6549         147242.66                                 Zion National Park
# 6550         147242.66                                 Zion National Park
# 6551         147242.66                                 Zion National Park
# 6552         147242.66                                 Zion National Park
# 6553         147242.66                                 Zion National Park
#
#                      Site_Name_y             Designation_y State List_y  \
# 0     Abraham Lincoln Birthplace  National Historical Park           KY
# 1     Abraham Lincoln Birthplace  National Historical Park           KY
# 2     Abraham Lincoln Birthplace  National Historical Park           KY
# 3     Abraham Lincoln Birthplace  National Historical Park           KY
# 4     Abraham Lincoln Birthplace  National Historical Park           KY
# ...                          ...                       ...          ...
# 6549                        Zion             National Park           UT
# 6550                        Zion             National Park           UT
# 6551                        Zion             National Park           UT
# 6552                        Zion             National Park           UT
# 6553                        Zion             National Park           UT
#
#        CEI Region
# 0     Ohio Valley
# 1     Ohio Valley
# 2     Ohio Valley
# 3     Ohio Valley
# 4     Ohio Valley
# ...           ...
# 6549    Southwest
# 6550    Southwest
# 6551    Southwest
# 6552    Southwest
# 6553    Southwest
#
# [6554 rows x 17 columns]

# %%
df1_t = pd.merge(df_t, nps_regions, on = 'Park_Code', how = 'left')

# %%
df1_t = pd.merge(df1_t, nino_load, on = 'Year', how = 'left')
df1_t.head()
# Out:
#   Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  annual_chg  \
# 0      ABLI  ABLI-1994  1994        78659.0              0.002252     -5589.0
# 1      ABLI  ABLI-1995  1995        75253.0              0.002154     -3406.0
# 2      ABLI  ABLI-1996  1996        69894.0              0.002001     -5359.0
# 3      ABLI  ABLI-1997  1997        73586.0              0.002106      3692.0
# 4      ABLI  ABLI-1998  1998        70560.0              0.002020     -3026.0
#
#    annual_chg_pct                                     Site_Full_Name  \
# 0       -0.066340  Abraham Lincoln Birthplace National Historical...
# 1       -0.043301  Abraham Lincoln Birthplace National Historical...
# 2       -0.071213  Abraham Lincoln Birthplace National Historical...
# 3        0.052823  Abraham Lincoln Birthplace National Historical...
# 4       -0.041122  Abraham Lincoln Birthplace National Historical...
#
#                     Site_Name               Designation State List  \
# 0  Abraham Lincoln Birthplace  National Historical Park         KY
# 1  Abraham Lincoln Birthplace  National Historical Park         KY
# 2  Abraham Lincoln Birthplace  National Historical Park         KY
# 3  Abraham Lincoln Birthplace  National Historical Park         KY
# 4  Abraham Lincoln Birthplace  National Historical Park         KY
#
#    Gross Area Acres       Region  RONI
# 0             344.5  Ohio Valley   0.3
# 1             344.5  Ohio Valley   1.3
# 2             344.5  Ohio Valley  -0.9
# 3             344.5  Ohio Valley  -0.2
# 4             344.5  Ohio Valley   2.2

# %%
# Add composite feature to be able to join nps data with cei data

df1_t['Region-Year'] = df1_t['Region'] + '-' + df1_t['Year'].astype(str)
df1_t.head()
# Out:
#   Park_Code  Code_Year  Year  Traffic Count  Traffic Count Scaled  annual_chg  \
# 0      ABLI  ABLI-1994  1994        78659.0              0.002252     -5589.0
# 1      ABLI  ABLI-1995  1995        75253.0              0.002154     -3406.0
# 2      ABLI  ABLI-1996  1996        69894.0              0.002001     -5359.0
# 3      ABLI  ABLI-1997  1997        73586.0              0.002106      3692.0
# 4      ABLI  ABLI-1998  1998        70560.0              0.002020     -3026.0
#
#    annual_chg_pct                                     Site_Full_Name  \
# 0       -0.066340  Abraham Lincoln Birthplace National Historical...
# 1       -0.043301  Abraham Lincoln Birthplace National Historical...
# 2       -0.071213  Abraham Lincoln Birthplace National Historical...
# 3        0.052823  Abraham Lincoln Birthplace National Historical...
# 4       -0.041122  Abraham Lincoln Birthplace National Historical...
#
#                     Site_Name               Designation State List  \
# 0  Abraham Lincoln Birthplace  National Historical Park         KY
# 1  Abraham Lincoln Birthplace  National Historical Park         KY
# 2  Abraham Lincoln Birthplace  National Historical Park         KY
# 3  Abraham Lincoln Birthplace  National Historical Park         KY
# 4  Abraham Lincoln Birthplace  National Historical Park         KY
#
#    Gross Area Acres       Region  RONI       Region-Year
# 0             344.5  Ohio Valley   0.3  Ohio Valley-1994
# 1             344.5  Ohio Valley   1.3  Ohio Valley-1995
# 2             344.5  Ohio Valley  -0.9  Ohio Valley-1996
# 3             344.5  Ohio Valley  -0.2  Ohio Valley-1997
# 4             344.5  Ohio Valley   2.2  Ohio Valley-1998

# %%
df2_t = pd.merge(df1_t, cei_data, on = 'Region-Year', how = 'left')
df2_t.head()
# Out:
#   Park_Code  Code_Year  Year_x  Traffic Count  Traffic Count Scaled  \
# 0      ABLI  ABLI-1994    1994        78659.0              0.002252
# 1      ABLI  ABLI-1995    1995        75253.0              0.002154
# 2      ABLI  ABLI-1996    1996        69894.0              0.002001
# 3      ABLI  ABLI-1997    1997        73586.0              0.002106
# 4      ABLI  ABLI-1998    1998        70560.0              0.002020
#
#    annual_chg  annual_chg_pct  \
# 0     -5589.0       -0.066340
# 1     -3406.0       -0.043301
# 2     -5359.0       -0.071213
# 3      3692.0        0.052823
# 4     -3026.0       -0.041122
#
#                                       Site_Full_Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1  Abraham Lincoln Birthplace National Historical...
# 2  Abraham Lincoln Birthplace National Historical...
# 3  Abraham Lincoln Birthplace National Historical...
# 4  Abraham Lincoln Birthplace National Historical...
#
#                     Site_Name               Designation State List  \
# 0  Abraham Lincoln Birthplace  National Historical Park         KY
# 1  Abraham Lincoln Birthplace  National Historical Park         KY
# 2  Abraham Lincoln Birthplace  National Historical Park         KY
# 3  Abraham Lincoln Birthplace  National Historical Park         KY
# 4  Abraham Lincoln Birthplace  National Historical Park         KY
#
#    Gross Area Acres     Region_x  RONI       Region-Year  Year_y  \
# 0             344.5  Ohio Valley   0.3  Ohio Valley-1994  1994.0
# 1             344.5  Ohio Valley   1.3  Ohio Valley-1995  1995.0
# 2             344.5  Ohio Valley  -0.9  Ohio Valley-1996  1996.0
# 3             344.5  Ohio Valley  -0.2  Ohio Valley-1997  1997.0
# 4             344.5  Ohio Valley   2.2  Ohio Valley-1998  1998.0
#
#    Percentage Area     Region_y
# 0           0.1642  Ohio Valley
# 1           0.0922  Ohio Valley
# 2           0.3412  Ohio Valley
# 3           0.1172  Ohio Valley
# 4           0.4344  Ohio Valley

# %%
# clean up data frame

df3_t = df2_t[['Code_Year','Traffic Count','Traffic Count Scaled','annual_chg','annual_chg_pct','Designation','Gross Area Acres','Region_x','Percentage Area','RONI']]
df3_t.rename(columns={"annual_chg": "trf_annual_chg", "annual_chg_pct": "trf_annual_chg_pct", "Region_x": "Region",'Percentage Area':'cei_pct_area'}, inplace=True)
df3_t.head()
# Out:
#    Code_Year  Traffic Count  Traffic Count Scaled  trf_annual_chg  \
# 0  ABLI-1994        78659.0              0.002252         -5589.0
# 1  ABLI-1995        75253.0              0.002154         -3406.0
# 2  ABLI-1996        69894.0              0.002001         -5359.0
# 3  ABLI-1997        73586.0              0.002106          3692.0
# 4  ABLI-1998        70560.0              0.002020         -3026.0
#
#    trf_annual_chg_pct               Designation  Gross Area Acres  \
# 0           -0.066340  National Historical Park             344.5
# 1           -0.043301  National Historical Park             344.5
# 2           -0.071213  National Historical Park             344.5
# 3            0.052823  National Historical Park             344.5
# 4           -0.041122  National Historical Park             344.5
#
#         Region  cei_pct_area  RONI
# 0  Ohio Valley        0.1642   0.3
# 1  Ohio Valley        0.0922   1.3
# 2  Ohio Valley        0.3412  -0.9
# 3  Ohio Valley        0.1172  -0.2
# 4  Ohio Valley        0.4344   2.2

# %%
df3_t.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6554 entries, 0 to 6553
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Code_Year             6554 non-null   str
#  1   Traffic Count         6554 non-null   float64
#  2   Traffic Count Scaled  6554 non-null   float64
#  3   trf_annual_chg        6554 non-null   float64
#  4   trf_annual_chg_pct    6554 non-null   float64
#  5   Designation           6554 non-null   str
#  6   Gross Area Acres      6518 non-null   float64
#  7   Region                6376 non-null   str
#  8   cei_pct_area          6376 non-null   float64
#  9   RONI                  6554 non-null   float64
# dtypes: float64(7), str(3)
# memory usage: 752.0 KB

# %%
df3_t = df3_t[df3_t['Region'].notna()]
df3_t.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6376 entries, 0 to 6553
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Code_Year             6376 non-null   str
#  1   Traffic Count         6376 non-null   float64
#  2   Traffic Count Scaled  6376 non-null   float64
#  3   trf_annual_chg        6376 non-null   float64
#  4   trf_annual_chg_pct    6376 non-null   float64
#  5   Designation           6376 non-null   str
#  6   Gross Area Acres      6340 non-null   float64
#  7   Region                6376 non-null   str
#  8   cei_pct_area          6376 non-null   float64
#  9   RONI                  6376 non-null   float64
# dtypes: float64(7), str(3)
# memory usage: 783.1 KB

# %% [markdown]
# ### Prepare Data for Modeling

# %%
df3.head()
# Out:
#    Code_Year  Visitors  Visitors Scaled  vis_annual_chg  vis_annual_chg_pct  \
# 0  ABLI-1980  239074.0         0.010983        -32157.0           -0.118559
# 1  ABLI-1981  252245.0         0.011588         13171.0            0.055092
# 2  ABLI-1982  318707.0         0.014642         66462.0            0.263482
# 3  ABLI-1983  256126.0         0.011767        -62581.0           -0.196359
# 4  ABLI-1984  258023.0         0.011854          1897.0            0.007407
#
#                 Designation  Gross Area Acres       Region  cei_pct_area  RONI
# 0  National Historical Park             344.5  Ohio Valley        0.1162   0.6
# 1  National Historical Park             344.5  Ohio Valley        0.1120   0.0
# 2  National Historical Park             344.5  Ohio Valley        0.1230   0.1
# 3  National Historical Park             344.5  Ohio Valley        0.0882   2.5
# 4  National Historical Park             344.5  Ohio Valley        0.0780  -0.5

# %%
df3.describe()
# Out:
#            Visitors  Visitors Scaled  vis_annual_chg  vis_annual_chg_pct  \
# count  1.649000e+04     16490.000000    1.649000e+04        16490.000000
# mean   8.241297e+05         0.037861    6.000037e+03            0.150409
# std    1.747376e+06         0.080276    2.715999e+05            4.122370
# min    0.000000e+00         0.000000   -6.489533e+06           -1.000000
# 25%    5.591450e+04         0.002569   -1.349575e+04           -0.070929
# 50%    2.400470e+05         0.011028    7.725000e+02            0.008937
# 75%    8.445820e+05         0.038801    2.270600e+04            0.097652
# max    2.176718e+07         1.000000    7.100646e+06          476.542373
#
#        Gross Area Acres  cei_pct_area          RONI
# count      1.649000e+04  16490.000000  16490.000000
# mean       1.025743e+05      0.228245     -0.021352
# std        2.972692e+05      0.153476      1.110185
# min        2.000000e-02      0.000000     -1.700000
# 25%        1.999600e+02      0.118400     -0.900000
# 50%        3.444320e+03      0.190000     -0.100000
# 75%        6.470122e+04      0.338800      0.600000
# max        3.408375e+06      0.718600      2.500000

# %%
df3.to_csv('DT_data_set_init.csv')

# %% [markdown]
# #### Visitor Data

# %%
df3[df3["vis_annual_chg_pct"]==0]
# Out:
# Empty DataFrame
# Columns: [Code_Year, Visitors, Visitors Scaled, vis_annual_chg, vis_annual_chg_pct, Designation, Gross Area Acres, Region, cei_pct_area, RONI]
# Index: []

# %%
# visitor annual change
vis_trend = [
    df3["vis_annual_chg_pct"] <= -1,
    (df3["vis_annual_chg_pct"] > -1) & (df3["vis_annual_chg_pct"] <= -0.1),
    (df3["vis_annual_chg_pct"] > -0.1) & (df3["vis_annual_chg_pct"] < 0),
     (df3["vis_annual_chg_pct"] >= 0) & (df3["vis_annual_chg_pct"] < 0.1),
    (df3["vis_annual_chg_pct"] < 1) & (df3["vis_annual_chg_pct"] >= 0.1),
    df3["vis_annual_chg_pct"] >= 1
]

vt_cat = ['Sig Decr','Decrease', 'Minimal Change','Minimal Change', 'Increase', 'Sig Incr']
vt_bins = [-10, -1, 0, 0, 1, 10]
vt_chg = [1, 1, 0, 0, 1, 1]
vt_updn = [0, 0, 0, 1, 1, 1]
vt_sigchg = [1, 0, 0, 0, 0, 1]

# %%
# Add categorial features where available

df3['Visitor Trend Cat'] = np.select(vis_trend, vt_cat, default='Minimal Change')
df3['Visitor Trend Bins'] = np.select(vis_trend, vt_bins, default=0)
df3['Visitor Trend Chg'] = np.select(vis_trend, vt_chg, default=0)
df3['Visitor Trend UpDn'] = np.select(vis_trend, vt_updn, default=0)
df3['Visitor Trend SigChg'] = np.select(vis_trend, vt_sigchg, default=0)

# %%
#df3[(df3['vis_annual_chg_pct']<0.1) & (df3['vis_annual_chg_pct']> -0.1)]

# %%
sns.histplot(data = df3, x = 'vis_annual_chg_pct')
plt.show()

# %%
sns.countplot(data = df3, x = 'Visitor Trend Cat')
plt.show()

# %% [markdown]
# #### Categorization of Features

# %%
# Add descriptors and categories for each year based on RONI values
nino_cat = [
    df3['RONI'] >= 2,
    df3['RONI'] >= 1.5,
    df3['RONI'] >= 1.0,
    df3['RONI'] >= 0.5,
    df3['RONI'] > -0.5,
    df3['RONI'] > -1.0,
    df3['RONI'] > -1.5,
    df3['RONI'] > -2.0,
   df3['RONI'] <= -2.0,

]

cat = ['El Niño','El Niño','El Niño','El Niño','Neutral','La Niña','La Niña','La Niña','La Niña']

rank = ['Very Strong','Strong','Moderate','Weak','Neutral','Weak','Moderate','Strong','Very Strong']

ranked_cat = ['Very Strong El Niño','Strong El Niño','Moderate El Niño','Weak El Niño','Neutral','Weak La Niña','Moderate La Niña','Strong La Niña','Very Strong La Niña']

df3['RONI Event'] = np.select(nino_cat,cat,default = 'Neutral')
df3['RONI Intensity'] = np.select(nino_cat,rank,default = 'Neutral')
df3['RONI Desc'] = np.select(nino_cat,ranked_cat,default = 'Neutral')

#df3.head(10)

# %%
# Add categories for each year based on CEI values
cei_bin = [
    df3['cei_pct_area'] >= 0.4,
    df3['cei_pct_area']  > 0.2,
    df3['cei_pct_area'] <= 0.2
    ]

cei_cat = ['Extreme','Increased','Nominal']

df3['CEI Cat'] = np.select(cei_bin,cei_cat,default = 'Nominal')

#df3.head(10)

# %%
# Add categories for each year based on CEI values
ga_bin = [
    df3['Gross Area Acres'] <= 1,
    (df3['Gross Area Acres']  > 1) & (df3['Gross Area Acres']  <= 10) ,
    (df3['Gross Area Acres']  > 10) & (df3['Gross Area Acres']  <= 100) ,
    (df3['Gross Area Acres']  > 100) & (df3['Gross Area Acres']  <= 1000) ,
    (df3['Gross Area Acres']  > 1000) & (df3['Gross Area Acres']  <= 10000) ,
    (df3['Gross Area Acres']  > 10000) & (df3['Gross Area Acres']  <= 100000) ,
    df3['Gross Area Acres'] >= 100000
    ]

ga_cat = ['Tiny','Very Small','Small','Medium','Large','Very Large','Gargantuan']

df3['GAA Cat'] = np.select(ga_bin,ga_cat,default = 'Tiny')

#df3.head(10)

# %%
# Create binary category for National Park (1) or Other Designation (0)

NatlParksDesig = ['National Park', 'National Parks', 'National Park & Preserve']

df3['Desig_NatlPark'] = np.where(df3['Designation'].isin(NatlParksDesig), 1, 0)

# %%
df3.head()
# Out:
#    Code_Year  Visitors  Visitors Scaled  vis_annual_chg  vis_annual_chg_pct  \
# 0  ABLI-1980  239074.0         0.010983        -32157.0           -0.118559
# 1  ABLI-1981  252245.0         0.011588         13171.0            0.055092
# 2  ABLI-1982  318707.0         0.014642         66462.0            0.263482
# 3  ABLI-1983  256126.0         0.011767        -62581.0           -0.196359
# 4  ABLI-1984  258023.0         0.011854          1897.0            0.007407
#
#                 Designation  Gross Area Acres       Region  cei_pct_area  \
# 0  National Historical Park             344.5  Ohio Valley        0.1162
# 1  National Historical Park             344.5  Ohio Valley        0.1120
# 2  National Historical Park             344.5  Ohio Valley        0.1230
# 3  National Historical Park             344.5  Ohio Valley        0.0882
# 4  National Historical Park             344.5  Ohio Valley        0.0780
#
#    RONI  ... Visitor Trend Bins  Visitor Trend Chg  Visitor Trend UpDn  \
# 0   0.6  ...                 -1                  1                   0
# 1   0.0  ...                  0                  0                   1
# 2   0.1  ...                  1                  1                   1
# 3   2.5  ...                 -1                  1                   0
# 4  -0.5  ...                  0                  0                   1
#
#    Visitor Trend SigChg  RONI Event RONI Intensity            RONI Desc  \
# 0                     0     El Niño           Weak         Weak El Niño
# 1                     0     Neutral        Neutral              Neutral
# 2                     0     Neutral        Neutral              Neutral
# 3                     0     El Niño    Very Strong  Very Strong El Niño
# 4                     0     La Niña           Weak         Weak La Niña
#
#    CEI Cat GAA Cat Desig_NatlPark
# 0  Nominal  Medium              0
# 1  Nominal  Medium              0
# 2  Nominal  Medium              0
# 3  Nominal  Medium              0
# 4  Nominal  Medium              0
#
# [5 rows x 21 columns]

# %%
k = df3[['Code_Year','GAA Cat']]
ks = k['Code_Year'].str.split("-", n=1, expand=True)

k1 = pd.concat([k,ks],axis = 1)

k1.head()

k2 = k1[[0,'GAA Cat']].drop_duplicates()
k2
#sns.countplot(data = k1, x = 'GAA Cat')
#plt.show()
# Out:
#           0     GAA Cat
# 0      ABLI      Medium
# 46     ACAD  Very Large
# 92     ADAM       Small
# 138    AFBG        Tiny
# 153    AGFO       Large
# ...     ...         ...
# 17663  WRBR      Medium
# 17709  WUPA  Very Large
# 17755  YELL  Gargantuan
# 17801  YOSE  Gargantuan
# 17890  ZION  Gargantuan
#
# [367 rows x 2 columns]

# %%
sns.histplot(data = k2, x = 'GAA Cat')
plt.show()

# %%
### Apply One Hot Encoding for categorical data

# %%
df3.head()
# Out:
#    Code_Year  Visitors  Visitors Scaled  vis_annual_chg  vis_annual_chg_pct  \
# 0  ABLI-1980  239074.0         0.010983        -32157.0           -0.118559
# 1  ABLI-1981  252245.0         0.011588         13171.0            0.055092
# 2  ABLI-1982  318707.0         0.014642         66462.0            0.263482
# 3  ABLI-1983  256126.0         0.011767        -62581.0           -0.196359
# 4  ABLI-1984  258023.0         0.011854          1897.0            0.007407
#
#                 Designation  Gross Area Acres       Region  cei_pct_area  \
# 0  National Historical Park             344.5  Ohio Valley        0.1162
# 1  National Historical Park             344.5  Ohio Valley        0.1120
# 2  National Historical Park             344.5  Ohio Valley        0.1230
# 3  National Historical Park             344.5  Ohio Valley        0.0882
# 4  National Historical Park             344.5  Ohio Valley        0.0780
#
#    RONI  ... Visitor Trend Bins  Visitor Trend Chg  Visitor Trend UpDn  \
# 0   0.6  ...                 -1                  1                   0
# 1   0.0  ...                  0                  0                   1
# 2   0.1  ...                  1                  1                   1
# 3   2.5  ...                 -1                  1                   0
# 4  -0.5  ...                  0                  0                   1
#
#    Visitor Trend SigChg  RONI Event RONI Intensity            RONI Desc  \
# 0                     0     El Niño           Weak         Weak El Niño
# 1                     0     Neutral        Neutral              Neutral
# 2                     0     Neutral        Neutral              Neutral
# 3                     0     El Niño    Very Strong  Very Strong El Niño
# 4                     0     La Niña           Weak         Weak La Niña
#
#    CEI Cat GAA Cat Desig_NatlPark
# 0  Nominal  Medium              0
# 1  Nominal  Medium              0
# 2  Nominal  Medium              0
# 3  Nominal  Medium              0
# 4  Nominal  Medium              0
#
# [5 rows x 21 columns]

# %%
# select features to use for data set
df31 = df3[['cei_pct_area','RONI','Region','Desig_NatlPark', 'Gross Area Acres','Visitor Trend UpDn']] #'Designation',
features_init = ['cei_pct_area','RONI', 'Desig_NatlPark', 'Gross Area Acres']

# %%
# Collinearity checks (of numerical features before one hot encoding)

corr_v = df31[features_init].corr()
corr_v.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_c96f0_row0_col0, #T_c96f0_row1_col1, #T_c96f0_row2_col2, #T_c96f0_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c96f0_row0_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c96f0_row0_col2, #T_c96f0_row0_col3, #T_c96f0_row3_col0, #T_c96f0_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c96f0_row1_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c96f0_row1_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c96f0_row1_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c96f0_row2_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c96f0_row2_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c96f0_row2_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c96f0_row3_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# </style>
# <table id="T_c96f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c96f0_level0_col0" class="col_heading level0 col0" >cei_pct_area</th>
#       <th id="T_c96f0_level0_col1" class="col_heading level0 col1" >RONI</th>
#       <th id="T_c96f0_level0_col2" class="col_heading level0 col2" >Desig_NatlPark</th>
#       <th id="T_c96f0_level0_col3" class="col_heading level0 col3" >Gross Area Acres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c96f0_level0_row0" class="row_heading level0 row0" >cei_pct_area</th>
#       <td id="T_c96f0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c96f0_row0_col1" class="data row0 col1" >0.064063</td>
#       <td id="T_c96f0_row0_col2" class="data row0 col2" >-0.000776</td>
#       <td id="T_c96f0_row0_col3" class="data row0 col3" >-0.040691</td>
#     </tr>
#     <tr>
#       <th id="T_c96f0_level0_row1" class="row_heading level0 row1" >RONI</th>
#       <td id="T_c96f0_row1_col0" class="data row1 col0" >0.064063</td>
#       <td id="T_c96f0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c96f0_row1_col2" class="data row1 col2" >0.008226</td>
#       <td id="T_c96f0_row1_col3" class="data row1 col3" >0.004144</td>
#     </tr>
#     <tr>
#       <th id="T_c96f0_level0_row2" class="row_heading level0 row2" >Desig_NatlPark</th>
#       <td id="T_c96f0_row2_col0" class="data row2 col0" >-0.000776</td>
#       <td id="T_c96f0_row2_col1" class="data row2 col1" >0.008226</td>
#       <td id="T_c96f0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c96f0_row2_col3" class="data row2 col3" >0.414869</td>
#     </tr>
#     <tr>
#       <th id="T_c96f0_level0_row3" class="row_heading level0 row3" >Gross Area Acres</th>
#       <td id="T_c96f0_row3_col0" class="data row3 col0" >-0.040691</td>
#       <td id="T_c96f0_row3_col1" class="data row3 col1" >0.004144</td>
#       <td id="T_c96f0_row3_col2" class="data row3 col2" >0.414869</td>
#       <td id="T_c96f0_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# apply one-hot encoding for categorical data
df31 = pd.get_dummies(df31)
df31.head()
# Out:
#    cei_pct_area  RONI  Desig_NatlPark  Gross Area Acres  Visitor Trend UpDn  \
# 0        0.1162   0.6               0             344.5                   0
# 1        0.1120   0.0               0             344.5                   1
# 2        0.1230   0.1               0             344.5                   1
# 3        0.0882   2.5               0             344.5                   0
# 4        0.0780  -0.5               0             344.5                   1
#
#    Region_Multiple  Region_Northeast  Region_Northern Rockies and Plains  \
# 0            False             False                               False
# 1            False             False                               False
# 2            False             False                               False
# 3            False             False                               False
# 4            False             False                               False
#
#    Region_Northwest  Region_Ohio Valley  Region_South  Region_Southeast  \
# 0             False                True         False             False
# 1             False                True         False             False
# 2             False                True         False             False
# 3             False                True         False             False
# 4             False                True         False             False
#
#    Region_Southwest  Region_Upper Midwest  Region_West
# 0             False                 False        False
# 1             False                 False        False
# 2             False                 False        False
# 3             False                 False        False
# 4             False                 False        False

# %% [markdown]
# #### X

# %%
# download data files

df3.to_csv('SVM_data_set_init.csv')
df31.to_csv('SVM_data_set_transf.csv')

# %%
df31.columns
# Out:
# Index(['cei_pct_area', 'RONI', 'Desig_NatlPark', 'Gross Area Acres',
#        'Visitor Trend UpDn', 'Region_Multiple', 'Region_Northeast',
#        'Region_Northern Rockies and Plains', 'Region_Northwest',
#        'Region_Ohio Valley', 'Region_South', 'Region_Southeast',
#        'Region_Southwest', 'Region_Upper Midwest', 'Region_West'],
#       dtype='str')

# %% [markdown]
# ### Select target parameter

# %%
target = 'Visitor Trend UpDn'

# %% [markdown]
# ### Features

# %%
features = ['cei_pct_area','RONI','Gross Area Acres','Desig_NatlPark','Region_Multiple', 'Region_Northeast',
       'Region_Northern Rockies and Plains', 'Region_Northwest',
       'Region_Ohio Valley', 'Region_South', 'Region_Southeast',
       'Region_Southwest', 'Region_Upper Midwest', 'Region_West']#

# %% [markdown]
# ### Check Correlation of Data

# %%
# Collinearity checks

corr_v = df31[features].corr()
corr_v.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_f625a_row0_col0, #T_f625a_row1_col1, #T_f625a_row2_col2, #T_f625a_row3_col3, #T_f625a_row4_col4, #T_f625a_row5_col5, #T_f625a_row6_col6, #T_f625a_row7_col7, #T_f625a_row8_col8, #T_f625a_row9_col9, #T_f625a_row10_col10, #T_f625a_row11_col11, #T_f625a_row12_col12, #T_f625a_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col1, #T_f625a_row6_col13, #T_f625a_row8_col9, #T_f625a_row8_col10, #T_f625a_row9_col6, #T_f625a_row9_col13 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col2, #T_f625a_row4_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col4, #T_f625a_row4_col0, #T_f625a_row5_col2, #T_f625a_row5_col3, #T_f625a_row8_col1, #T_f625a_row9_col1, #T_f625a_row10_col1, #T_f625a_row10_col3, #T_f625a_row10_col5, #T_f625a_row10_col6, #T_f625a_row10_col7, #T_f625a_row10_col8, #T_f625a_row10_col9, #T_f625a_row10_col11, #T_f625a_row10_col12, #T_f625a_row10_col13, #T_f625a_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f625a_row0_col6, #T_f625a_row1_col13, #T_f625a_row10_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col8, #T_f625a_row12_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col9, #T_f625a_row12_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col10, #T_f625a_row3_col11 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col11, #T_f625a_row1_col10, #T_f625a_row6_col4, #T_f625a_row9_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col12, #T_f625a_row3_col8, #T_f625a_row11_col2, #T_f625a_row12_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f625a_row0_col13 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f625a_row1_col2, #T_f625a_row4_col11, #T_f625a_row6_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col3, #T_f625a_row1_col5, #T_f625a_row2_col11, #T_f625a_row13_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col6, #T_f625a_row2_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col8, #T_f625a_row12_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col11, #T_f625a_row2_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f625a_row1_col12, #T_f625a_row2_col9, #T_f625a_row8_col5, #T_f625a_row12_col13 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col1, #T_f625a_row4_col1, #T_f625a_row6_col1, #T_f625a_row12_col1, #T_f625a_row13_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_f625a_row2_col4, #T_f625a_row13_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f625a_row2_col5, #T_f625a_row6_col7, #T_f625a_row8_col13, #T_f625a_row9_col2, #T_f625a_row9_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col7, #T_f625a_row3_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f625a_row2_col8, #T_f625a_row4_col12, #T_f625a_row7_col13 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col10, #T_f625a_row4_col7, #T_f625a_row4_col10, #T_f625a_row8_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col12, #T_f625a_row4_col6, #T_f625a_row6_col5, #T_f625a_row13_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f625a_row2_col13 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f625a_row3_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f625a_row3_col1, #T_f625a_row3_col5, #T_f625a_row11_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f625a_row3_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f625a_row3_col4, #T_f625a_row5_col4, #T_f625a_row11_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f625a_row3_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_f625a_row3_col9, #T_f625a_row3_col12, #T_f625a_row6_col9, #T_f625a_row9_col8, #T_f625a_row9_col10, #T_f625a_row13_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f625a_row3_col10, #T_f625a_row11_col12 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f625a_row3_col13 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f625a_row4_col2, #T_f625a_row9_col0, #T_f625a_row11_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f625a_row4_col3, #T_f625a_row12_col7, #T_f625a_row12_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f625a_row4_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f625a_row4_col9, #T_f625a_row8_col7, #T_f625a_row12_col8, #T_f625a_row13_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f625a_row4_col13, #T_f625a_row6_col11, #T_f625a_row9_col5, #T_f625a_row9_col11, #T_f625a_row12_col6, #T_f625a_row12_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col0, #T_f625a_row6_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f625a_row5_col1, #T_f625a_row5_col10, #T_f625a_row7_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col6, #T_f625a_row5_col9, #T_f625a_row5_col13, #T_f625a_row7_col10, #T_f625a_row7_col12, #T_f625a_row11_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col7, #T_f625a_row13_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col8, #T_f625a_row11_col6, #T_f625a_row11_col9, #T_f625a_row11_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col11, #T_f625a_row7_col6, #T_f625a_row7_col9, #T_f625a_row13_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f625a_row5_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f625a_row6_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f625a_row6_col8, #T_f625a_row6_col10, #T_f625a_row13_col8, #T_f625a_row13_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f625a_row6_col12, #T_f625a_row8_col2, #T_f625a_row9_col12, #T_f625a_row11_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f625a_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f625a_row7_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f625a_row7_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f625a_row7_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f625a_row7_col5, #T_f625a_row7_col11, #T_f625a_row8_col6, #T_f625a_row13_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f625a_row7_col8, #T_f625a_row8_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f625a_row8_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f625a_row8_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f625a_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f625a_row9_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f625a_row10_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_f625a_row10_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f625a_row11_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f625a_row11_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f625a_row12_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f625a_row12_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f625a_row13_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_f625a_row13_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# </style>
# <table id="T_f625a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f625a_level0_col0" class="col_heading level0 col0" >cei_pct_area</th>
#       <th id="T_f625a_level0_col1" class="col_heading level0 col1

# %%
# Test & training split (20/80)

X_train, X_test, y_train, y_test = train_test_split(df31[features], df31[target], test_size = 0.2, random_state=0)

# %%
# Check distribution of target counts 

# in training set
display(y_train.value_counts())

# in est set
display(y_test.value_counts())
# Out:
# Visitor Trend UpDn
# 1    7059
# 0    6133
# Name: count, dtype: int64
# Visitor Trend UpDn
# 1    1756
# 0    1542
# Name: count, dtype: int64

# %%
# display the data after splitting

# Training set
display(pd.DataFrame(X_train).head())
display(pd.DataFrame(y_train).head())

# Test set
display(pd.DataFrame(X_test).head())
display(pd.DataFrame(y_test).head())
# Out:
#       cei_pct_area  RONI  Gross Area Acres  Desig_NatlPark  Region_Multiple  \
# 5691       0.41260   1.2            720.60               0            False
# 7756       0.43560   0.6             62.04               0            False
# 773        0.00165   0.7          41311.27               0             True
# 3984       0.19300   1.3           1347.21               0            False
# 7150       0.44500   2.2          23777.22               1            False
#
#       Region_Northeast  Region_Northern Rockies and Plains  Region_Northwest  \
# 5691             False                               False             False
# 7756             False                               False             False
# 773              False                               False             False
# 3984             False                                True             False
# 7150             False                                True             False
#
#       Region_Ohio Valley  Region_South  Region_Southeast  Region_Southwest  \
# 5691               False         False             False              True
# 7756               False         False              True             False
# 773                False         False             False             False
# 3984               False         False             False             False
# 7150               False         False             False             False
#
#       Region_Upper Midwest  Region_West
# 5691                 False        False
# 7756                 False        False
# 773                  False        False
# 3984                 False        False
# 7150                 False        False
#       Visitor Trend UpDn
# 5691                   0
# 7756                   0
# 773                    0
# 3984                   0
# 7150                   1
#        cei_pct_area  RONI  Gross Area Acres  Desig_NatlPark  Region_Multiple  \
# 10573        0.1170   0.3            765.34               0            False
# 14301        0.2794   2.2         117574.59               1            False
# 13186        0.1320  -1.2         221390.21               1            False
# 16617        0.3496  -1.1          74999.56               0            False
# 1867         0.1110   0.6            235.37               0            False
#
#        Region_Northeast  Region_Northern Rockies and Plains  Region_Northwest  \
# 10573             False                                True             False
# 14301             False                               False              True
# 13186             False                               False             False
# 16617              True                               False             False
# 1867              False                               False             False
#
#        Region_Ohio Valley  Region_South  Region_Southeast  Region_Southwest  \
# 10573               False         False             False             False
# 14301               False         False             False             False
# 13186               False         False             False              True
# 16617               False         False             False             False
# 1867                False          True             False             False
#
#        Region_Upper Midwest  Region_West
# 10573                 False        False
# 14301                 False        False
# 13186                 False        False
# 16617                 False        False
# 1867                  False        False
#        Visitor Trend UpDn
# 10573                   1
# 14301                   1
# 13186                   0
# 16617                   0
# 1867                    1

# %%
pd.DataFrame(X_train).to_csv('SVM_data_set_train.csv')

# %%
# scale data 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
# Visitor Training Data
display(pd.DataFrame(X_train).head())
# Out:
#          0         1         2         3         4        5         6   \
# 0  1.200491  1.087938 -0.342817 -0.562526 -0.205595 -0.40298 -0.288402
# 1  1.350198  0.547885 -0.345010 -0.562526 -0.205595 -0.40298 -0.288402
# 2 -1.474383  0.637894 -0.207679 -0.562526  4.863943 -0.40298 -0.288402
# 3 -0.228886  1.177947 -0.340731 -0.562526 -0.205595 -0.40298  3.467377
# 4  1.411382  1.988026 -0.266055  1.777696 -0.205595 -0.40298  3.467377
#
#          7         8         9         10        11        12        13
# 0 -0.340697 -0.261275 -0.281718 -0.553765  2.386011 -0.185754 -0.302955
# 1 -0.340697 -0.261275 -0.281718  1.805819 -0.419110 -0.185754 -0.302955
# 2 -0.340697 -0.261275 -0.281718 -0.553765 -0.419110 -0.185754 -0.302955
# 3 -0.340697 -0.261275 -0.281718 -0.553765 -0.419110 -0.185754 -0.302955
# 4 -0.340697 -0.261275 -0.281718 -0.553765 -0.419110 -0.185754 -0.302955

# %%
pd.DataFrame(X_train).to_csv('SVM_data_set_scaled_train.csv')

# %% [markdown]
# #### Support Vector Machine Set Up

# %%
# Examine linear, poly and rbf kernels

# Configure model
class_linear = SVC(kernel='linear')
class_poly = SVC(kernel = 'poly')
class_rbf = SVC(kernel = 'rbf')

# Fit model
class_linear.fit(X_train, y_train)
class_poly.fit(X_train, y_train)
class_rbf.fit(X_train, y_train)

# Prediction of results
pred_linear = class_linear.predict(sc.transform(X_test))
pred_poly = class_poly.predict(sc.transform(X_test))
pred_rbf = class_rbf.predict(sc.transform(X_test))

# %%
# Generating the confusion matrix for each type of kernel

# Linear Kernel
cm_linear = confusion_matrix(y_test, pred_linear)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_linear, display_labels=class_linear.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Simple SVM with Linear Kernel')

# Poly Kernel
cm_poly = confusion_matrix(y_test, pred_poly)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_poly, display_labels=class_poly.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Simple SVM with Poly Kernel')

# RBF Kernel
cm_rbf = confusion_matrix(y_test, pred_rbf)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_rbf, display_labels=class_rbf.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Simple SVM with RBF Kernel')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Simple SVM with RBF Kernel')

# %%
# Accuracy, F1 Score and Recall Scores

accuracy_linear = accuracy_score(y_test, pred_linear)
f1_linear = f1_score(y_test, pred_linear)
recall_linear = recall_score(y_test, pred_linear)
accuracy_poly = accuracy_score(y_test, pred_poly)
f1_poly = f1_score(y_test, pred_poly)
recall_poly = recall_score(y_test, pred_poly)
accuracy_rbf = accuracy_score(y_test, pred_rbf)
f1_rbf = f1_score(y_test, pred_rbf)
recall_rbf= recall_score(y_test, pred_rbf)


# Adding the scores to a dataframe
scores = pd.DataFrame({'Kernel': ['Linear', 'Poly', 'RBF']})
scores['Accuracy'] = [accuracy_linear, accuracy_poly, accuracy_rbf]
scores['F1 Score'] = [f1_linear, f1_poly, f1_rbf]
scores['Recall'] = [recall_linear, recall_poly, recall_rbf]

# Displaying the scores
display(scores)
# Out:
#    Kernel  Accuracy  F1 Score    Recall
# 0  Linear  0.532444  0.694895  1.000000
# 1    Poly  0.548514  0.656675  0.810934
# 2     RBF  0.550637  0.659467  0.817198

# %% [markdown]
# ### Optimization

# %%
# Implementing SVM with GridSearchCV for hyperparameter tuning of linear, rbf and poly kernels

# %%
# GridSearchCV for Accuracy
# Implementing SVM with GridSearchCV for hyperparameter tuning of linear, rbf and poly kernels

params_grid_acc = [{'C':[0.1,0.5,1], 'kernel':['linear']},
               {'C':[1,5,10], 'kernel':['poly'], 'degree':[2,3,4]},
               {'C':[0.1,0.5,1,5], 'kernel':['rbf']}]

classifier = SVC()
grid_search_acc = GridSearchCV(estimator = classifier, 
                           param_grid = params_grid_acc,
                           scoring = 'accuracy',
                           cv = 10, 
                           n_jobs = -1)

grid_search_acc.fit(X_train, y_train)

# Displaying the best parameters
best_accuracy = grid_search_acc.best_score_
best_acc_parameters = grid_search_acc.best_params_

print('Best Accuracy:', best_accuracy)
print('Best Parameters:', best_acc_parameters)

#Best Accuracy: 0.5350970661888024
#Best Parameters: {'C': 0.1, 'kernel': 'linear'}

#Best Accuracy: 0.5447997794472397
#Best Parameters: {'C': 10, 'degree': 4, 'kernel': 'poly'}



#Best Accuracy: 0.5462406092770006
#Best Parameters: {'C': 5, 'kernel': 'rbf'}
# Out:
# Best Accuracy: 0.5462406092770006
# Best Parameters: {'C': 5, 'kernel': 'rbf'}

# %%
# GridSearchCV for Recall
# Implementing SVM with GridSearchCV for hyperparameter tuning of linear, rbf and poly kernels

params_grid_rec = [#{'C':[0.1,0.5,1], 'kernel':['linear']}]#,
               #{'C':[0.1,0.5,1,5,10], 'kernel':['poly'], 'degree':[2,3,4]}]#,
               {'C':[0.1,0.5,1], 'kernel':['rbf']}]

grid_search_rec = GridSearchCV(estimator = classifier, 
                           param_grid = params_grid_rec,
                           scoring = 'recall',
                           cv = 10, 
                           n_jobs = -1)

grid_search_rec.fit(X_train, y_train)


# Displaying the best parameters
best_recall = grid_search_rec.best_score_
best_rec_parameters = grid_search_rec.best_params_

print('Best Recall:', best_recall)
print('Best Parameters:', best_rec_parameters)

#Best Recall: 1.0
#Best Parameters: {'C': 0.1, 'kernel': 'linear'}

#Best Recall: 0.9869688385269122
#Best Parameters: {'C': 0.1, 'kernel': 'rbf'}


#Best Recall: 0.9873925622325357
#Best Parameters: {'C': 0.1, 'degree': 2, 'kernel': 'poly'}
# Out:
# Best Recall: 0.9869688385269122
# Best Parameters: {'C': 0.1, 'kernel': 'rbf'}

# %%
# GridSearchCV for F1

params_grid_f1 = [{'C':[0.1,0.5,1], 'kernel':['linear']}, # 
               {'C':[0.1,0.5,1], 'kernel':['poly'], 'degree':[2,3,4]},
               {'C':[0.1,0.5,1], 'kernel':['rbf']}]

grid_search_f1= GridSearchCV(estimator = classifier, 
                           param_grid = params_grid_f1,
                           scoring = 'f1',
                           cv = 10, 
                           n_jobs = -1)

grid_search_f1.fit(X_train, y_train)


# Displaying the best parameters
best_f1 = grid_search_f1.best_score_
best_f1_parameters = grid_search_f1.best_params_

print('Best F1:', best_f1)
print('Best Parameters:', best_f1_parameters)

#Best F1: 0.6937621768391794
#Best Parameters: {'C': 0.1, 'degree': 2, 'kernel': 'poly'}

#Best F1: 0.6943472478321071
#Best Parameters: {'C': 0.1, 'kernel': 'rbf'}


#Best F1: 0.6971507536173116
#Best Parameters: {'C': 0.1, 'kernel': 'linear'}
# Out:
# Best F1: 0.6943472478321071
# Best Parameters: {'C': 0.1, 'kernel': 'rbf'}

# %%
# Fit best SVM to training set (*** set classifier parameters based on analysis above ***)

# %%
# Best for Accuracy: 
#Best Accuracy: 0.5462406092770006
#Best Parameters: {'C': 5, 'kernel': 'rbf'}

classifier = SVC(kernel = 'rbf', C=5)

#classifier = 
classifier.fit(X_train, y_train)

# Predicting the Test set results
preds_rbf = classifier.predict(sc.transform(X_test))

# %%
# Confusion matrix for selected model
cm = confusion_matrix(y_test, preds_rbf)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Hyperparameter Tuned SVM - Best for Accuracy (Kernel = RBF / C = 5)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Hyperparameter Tuned SVM - Best for Accuracy (Kernel = RBF / C = 5)')

# %%
# Performance scores for selected model
accuracy = accuracy_score(y_test, preds_rbf)
f1 = f1_score(y_test, preds_rbf)
recall = recall_score(y_test, preds_rbf)

print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
print(f'Recall Score: {recall}')
# Out:
# Accuracy: 0.5442692540933899
# F1 Score: 0.6507088078085057
# Recall Score: 0.7972665148063781

# %%
X_test.head()
# Out:
#        cei_pct_area  RONI  Gross Area Acres  Desig_NatlPark  Region_Multiple  \
# 10573        0.1170   0.3            765.34               0            False
# 14301        0.2794   2.2         117574.59               1            False
# 13186        0.1320  -1.2         221390.21               1            False
# 16617        0.3496  -1.1          74999.56               0            False
# 1867         0.1110   0.6            235.37               0            False
#
#        Region_Northeast  Region_Northern Rockies and Plains  Region_Northwest  \
# 10573             False                                True             False
# 14301             False                               False              True
# 13186             False                               False             False
# 16617              True                               False             False
# 1867              False                               False             False
#
#        Region_Ohio Valley  Region_South  Region_Southeast  Region_Southwest  \
# 10573               False         False             False             False
# 14301               False         False             False             False
# 13186               False         False             False              True
# 16617               False         False             False             False
# 1867                False          True             False             False
#
#        Region_Upper Midwest  Region_West
# 10573                 False        False
# 14301                 False        False
# 13186                 False        False
# 16617                 False        False
# 1867                  False        False

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = y_test, cmap = "spring_r")
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Truth)')
plt.colorbar()
plt.show()

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = preds_rbf, cmap = 'summer_r')
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Predict - RBF)')
plt.colorbar()
plt.show()

# %%
# Best for Recall: 
#Best Recall: 0.9873925622325357
#Best Parameters: {'C': 0.1, 'degree': 2, 'kernel': 'poly'}

classifier = SVC(kernel = 'poly', C=0.1, degree = 2)

#classifier = 
classifier.fit(X_train, y_train)

# Predicting the Test set results
preds_poly = classifier.predict(sc.transform(X_test))

# %%
# Confusion matrix for selected model
cm = confusion_matrix(y_test, preds_poly)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Hyperparameter Tuned SVM - Best for Recall (Kernel = Poly (Deg 2) / C = 0.1)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Hyperparameter Tuned SVM - Best for Recall (Kernel = Poly (Deg 2) / C = 0.1)')

# %%
# Performance scores for selected model
accuracy = accuracy_score(y_test, preds_poly)
f1 = f1_score(y_test, preds_poly)
recall = recall_score(y_test, preds_poly)

print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
print(f'Recall Score: {recall}')
# Out:
# Accuracy: 0.5318374772589448
# F1 Score: 0.6935291782453354
# Recall Score: 0.994874715261959

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = y_test, cmap = "spring_r")
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Truth)')
plt.colorbar()
plt.show()

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = preds_poly, cmap = 'summer_r')
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Predict - Poly)')
plt.colorbar()
plt.show()

# %%
# Best for F1: 
#Best F1: 0.6971507536173116
#Best Parameters: {'C': 0.1, 'kernel': 'linear'}

classifier = SVC(kernel = 'linear', C=0.1)

#classifier = 
classifier.fit(X_train, y_train)

# Predicting the Test set results
preds_lin = classifier.predict(sc.transform(X_test))

# %%
# Confusion matrix for selected model
cm = confusion_matrix(y_test, preds_lin)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
disp.ax_.set_title('Confusion Matrix for Hyperparameter Tuned SVM - Best for F1 (Kernel = Linear / C = 0.1)')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Hyperparameter Tuned SVM - Best for F1 (Kernel = Linear / C = 0.1)')

# %%
# Performance scores for selected model
accuracy = accuracy_score(y_test, preds_lin)
f1 = f1_score(y_test, preds_lin)
recall = recall_score(y_test, preds_lin)

print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
print(f'Recall Score: {recall}')
# Out:
# Accuracy: 0.5324439053972104
# F1 Score: 0.6948951325682627
# Recall Score: 1.0

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = y_test, cmap = "spring_r")
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Truth)')
plt.colorbar()
plt.show()

# %%
plt.scatter(X_test['cei_pct_area'],X_test['RONI'], alpha = .8, c = preds_lin, cmap = 'summer_r')
plt.xlabel('CEI Percent Area')
plt.ylabel('RONI')
plt.title('RONI vs CEI Percentage Area (Visitor Inc/Dec Predict - Linear)')
plt.colorbar()
plt.show()
